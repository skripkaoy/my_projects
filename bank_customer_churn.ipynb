# %% [markdown]
# <h1>Содержание<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Подготовка-данных" data-toc-modified-id="Подготовка-данных-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Подготовка данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-библиотек" data-toc-modified-id="Загрузка-библиотек-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Загрузка библиотек</a></span></li><li><span><a href="#Функции" data-toc-modified-id="Функции-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Функции</a></span></li><li><span><a href="#Обзор-данных" data-toc-modified-id="Обзор-данных-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Обзор данных</a></span><ul class="toc-item"><li><span><a href="#Загрузка-данных" data-toc-modified-id="Загрузка-данных-1.3.1"><span class="toc-item-num">1.3.1&nbsp;&nbsp;</span>Загрузка данных</a></span></li><li><span><a href="#Изучение-общей-информации-о-данных" data-toc-modified-id="Изучение-общей-информации-о-данных-1.3.2"><span class="toc-item-num">1.3.2&nbsp;&nbsp;</span>Изучение общей информации о данных</a></span></li></ul></li></ul></li><li><span><a href="#Исследование-задачи" data-toc-modified-id="Исследование-задачи-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование задачи</a></span><ul class="toc-item"><li><span><a href="#Исследование-признаков" data-toc-modified-id="Исследование-признаков-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Исследование признаков</a></span></li><li><span><a href="#Предобработка-данных" data-toc-modified-id="Предобработка-данных-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Предобработка данных</a></span><ul class="toc-item"><li><span><a href="#Переименование-признаков" data-toc-modified-id="Переименование-признаков-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Переименование признаков</a></span></li><li><span><a href="#Разбиение-данных-на-выборки" data-toc-modified-id="Разбиение-данных-на-выборки-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Разбиение данных на выборки</a></span></li><li><span><a href="#Поиск-и-обработка-пропусков" data-toc-modified-id="Поиск-и-обработка-пропусков-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Поиск и обработка пропусков</a></span></li><li><span><a href="#Поиск-дубликатов" data-toc-modified-id="Поиск-дубликатов-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Поиск дубликатов</a></span></li><li><span><a href="#Изучение-выбросов" data-toc-modified-id="Изучение-выбросов-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>Изучение выбросов</a></span></li></ul></li><li><span><a href="#Выделение-признаков-и-целевого-признака" data-toc-modified-id="Выделение-признаков-и-целевого-признака-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Выделение признаков и целевого признака</a></span></li><li><span><a href="#Подготовка-признаков" data-toc-modified-id="Подготовка-признаков-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Подготовка признаков</a></span><ul class="toc-item"><li><span><a href="#Прямое-кодирование" data-toc-modified-id="Прямое-кодирование-2.4.1"><span class="toc-item-num">2.4.1&nbsp;&nbsp;</span>Прямое кодирование</a></span></li><li><span><a href="#Масштабирование-признаков" data-toc-modified-id="Масштабирование-признаков-2.4.2"><span class="toc-item-num">2.4.2&nbsp;&nbsp;</span>Масштабирование признаков</a></span></li></ul></li><li><span><a href="#Обучение-модели" data-toc-modified-id="Обучение-модели-2.5"><span class="toc-item-num">2.5&nbsp;&nbsp;</span>Обучение модели</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-2.5.1"><span class="toc-item-num">2.5.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-2.5.2"><span class="toc-item-num">2.5.2&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-2.5.3"><span class="toc-item-num">2.5.3&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li></ul></li><li><span><a href="#Борьба-с-дисбалансом" data-toc-modified-id="Борьба-с-дисбалансом-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Борьба с дисбалансом</a></span><ul class="toc-item"><li><span><a href="#Взвешивание-классов" data-toc-modified-id="Взвешивание-классов-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Взвешивание классов</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.1.1"><span class="toc-item-num">3.1.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.1.2"><span class="toc-item-num">3.1.2&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.1.3"><span class="toc-item-num">3.1.3&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Увеличение-выборки" data-toc-modified-id="Увеличение-выборки-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Увеличение выборки</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.2.1"><span class="toc-item-num">3.2.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.2.2"><span class="toc-item-num">3.2.2&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.2.3"><span class="toc-item-num">3.2.3&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li><li><span><a href="#Уменьшение-выборки" data-toc-modified-id="Уменьшение-выборки-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Уменьшение выборки</a></span><ul class="toc-item"><li><span><a href="#Логистическая-регрессия" data-toc-modified-id="Логистическая-регрессия-3.3.1"><span class="toc-item-num">3.3.1&nbsp;&nbsp;</span>Логистическая регрессия</a></span></li><li><span><a href="#Дерево-решений" data-toc-modified-id="Дерево-решений-3.3.2"><span class="toc-item-num">3.3.2&nbsp;&nbsp;</span>Дерево решений</a></span></li><li><span><a href="#Случайный-лес" data-toc-modified-id="Случайный-лес-3.3.3"><span class="toc-item-num">3.3.3&nbsp;&nbsp;</span>Случайный лес</a></span></li></ul></li></ul></li><li><span><a href="#Тестирование-модели" data-toc-modified-id="Тестирование-модели-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Тестирование модели</a></span></li><li><span><a href="#Общий-вывод" data-toc-modified-id="Общий-вывод-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Общий вывод</a></span></li><li><span><a href="#Чек-лист-готовности-проекта" data-toc-modified-id="Чек-лист-готовности-проекта-6"><span class="toc-item-num">6&nbsp;&nbsp;</span>Чек-лист готовности проекта</a></span></li></ul></div>

# %% [markdown]
# # Отток клиентов

# %% [markdown]
# **Цель исследования** — на основе исторических данных о поведении клиентов и расторжении договоров с банком «Бета-Банк» спрогнозировать, уйдёт клиент из банка в ближайшее время или нет. Для этого необходимо построить модель с предельно большим значением F1-меры (не менее 0.59). Это поможет бизнесу, так как банковские маркетологи посчитали: сохранять текущих клиентов дешевле, чем привлекать новых.
#
# **Ход исследования**
#
# В связи с тем, что о качестве данных ничего не известно, перед исследованием данных необходимо провести обзор данных. После проверки данных на ошибки, различные артефакты, пропуски найдем возможность исправить самые критичные ошибки данных. Затем уже будем обучать модели на обучающей выборке, вычислять метрики и подбирать гиперпараметры на валидационной выборке и тестировать лучшую модель на тестовой выборке.
#
# Таким образом, исследование пройдёт в четыре этапа:
#  1. Обзор данных.
#  2. Подготовка данных.
#  3. Подготовка признаков к построению моделей.
#  4. Построение моделей.
#  5. Тестирование.
#
# **Описание данных:**
# - **Признаки**
#
# `RowNumber` — индекс строки в данных
#
# `CustomerId` — уникальный идентификатор клиента
#
# `Surname` — фамилия
#
# `CreditScore` — кредитный рейтинг
#
# `Geography` — страна проживания
#
# `Gender` — пол
#
# `Age` — возраст
#
# `Tenure` — сколько лет человек является клиентом банка
#
# `Balance` — баланс на счёте
#
# `NumOfProducts` — количество продуктов банка, используемых клиентом
#
# `HasCrCard` — наличие кредитной карты
#
# `IsActiveMember` — активность клиента
#
# `EstimatedSalary` — предполагаемая зарплата
#
# - **Целевой признак**
#
# `Exited` — факт ухода клиента
#
# Источник данных: [https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling](https://www.kaggle.com/barelydedicated/bank-customer-churn-modeling)

# %% [markdown]
# ## Подготовка данных

# %% [markdown]
# ### Загрузка библиотек

# %% [markdown]
# Настроим окружение, импортируем все необходимые библиотеки, устанавливаем размер графиков.

# %%
# импорт библиотек
import pandas as pd
import matplotlib
import matplotlib.pyplot as plt
import seaborn as sns
import statistics
import re
import numpy as np
from matplotlib import rcParams, rcParamsDefault
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler, OneHotEncoder 
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import roc_auc_score, f1_score, precision_score, recall_score, roc_curve, precision_recall_curve
from sklearn.utils import shuffle
from tqdm import tqdm

rcParams['figure.figsize'] = 10,6

# %%
pd.options.mode.chained_assignment = None # убираем предупреждение SettingWithCopy

# %%
MY_RANDOM_STATE = np.random.seed(54321)

# %% [markdown]
# ### Функции

# %% [markdown]
# Функция, выводящая все необходимые нам характеристики для данных.

# %%
def dataframe_information(data):
    '''
    Функция принимает датафрейм для анализа и возвращает датафрейм с основными статистиками данных
    data - датафрейм
    Return:
    df_res - датафрейм с характеристиками данных
    '''
    
    df_data = []
    df_cols = ['name', 'object', 'na', 'zero', 'rate', 'unique', 'neg'
               , 'mean', 'moda', 'std', 'min', 'max', 'out left', 'out rigth', '25%', '50%', '75%']
    
    # перебираем столбцы в наборе данных
    for column_name in data.columns:
               
        # считаем характеристики
        column_type = data[column_name].dtypes
        column_na_values = data[column_name].isna().sum()
        column_zero_values = data[column_name][data[column_name] == 0].count()
        column_na_zero_rate = (column_na_values + column_zero_values) / data.shape[0]
        column_unique_values = data[column_name].nunique()
        column_negative_values = (data[column_name][data[column_name] < 0].count()
                                  if data[column_name].dtypes != 'object' else 0)
        column_mean = data[column_name].mean() if data[column_name].dtypes != 'object' else 0
        column_moda = statistics.mode(data[column_name])
        column_std = data[column_name].std() if data[column_name].dtypes != 'object' else 0
        column_min = data[column_name].min() if data[column_name].dtypes != 'object' else 0
        column_max = data[column_name].max() if data[column_name].dtypes != 'object' else 0
        outliers_left_number = (data[column_name][data[column_name] < data[column_name].quantile(.025)].count()
                                if data[column_name].dtypes != 'object' else 0)
        outliers_right_number = (data[column_name][data[column_name] > data[column_name].quantile(.975)].count()
                                 if data[column_name].dtypes != 'object' else 0)
        percentile_25 = data[column_name].quantile(.25) if data[column_name].dtypes != 'object' else 0
        percentile_50 = data[column_name].quantile(.50) if data[column_name].dtypes != 'object' else 0
        percentile_75 = data[column_name].quantile(.75) if data[column_name].dtypes != 'object' else 0
       
    # собираем показатели по каждому полю
        df_data.append([column_name, column_type, column_na_values
                                 , column_zero_values, column_na_zero_rate, column_unique_values
                                 , column_negative_values, column_mean, column_moda, column_std, column_min
                                 , column_max, outliers_left_number, outliers_right_number
                                 , percentile_25, percentile_50, percentile_75])
    
    # формируем набор данных
    df_res = pd.DataFrame(data = df_data, columns = df_cols)
    
    return df_res

# %% [markdown]
# Функция для поиска выбросов.

# %%
def search_outliers(data, col, col_name=None):
    '''
    Функция принимает датафрейм и столбец, ищет выбросы с помощью IQR и строит boxplot
    data - датафрейм
    col - столбец датафрейма
    col_name - наименование столбца (для графика)
    Return:
    lower_fence - верхняя граница нормальных значений
    upper_fence - нижняя граница нормальных значений
    '''
    
    Q3 = np.quantile(data[col], 0.75, axis=0)
    Q1 = np.quantile(data[col], 0.25, axis=0)
    IQR = Q3 - Q1
    upper_fence = round(Q3 + 1.5 * IQR, 2)
    lower_fence = round(Q1 - 1.5 * IQR, 2)
    if round(Q1 - 1.5 * IQR, 2)<0:
        lower_fence = 0
    print('_' * 45)
    print(f'Интервал фактических значений для переменной {col} от {round(data[col].min(),2)} до {round(data[col].max(),2)}')
    print(f'Интервал нормальных значений для переменной {col} от {lower_fence} до {upper_fence}')

    print(f'Переменная {col} содержит аномальных значений : {round(data[(data[col]>upper_fence)| (data[col]<lower_fence)].shape[0]/data.shape[0]*100, 2)}%')

    if data[(data[col] == 0)].shape[0]>0:
        print(f'Переменная {col} содержит нулевые значения {round(data[(data[col] == 0)].shape[0]/data.shape[0]*100, 2)}%')
 
    #  строим диаграмму размаха    
    if col_name != None:
        data.loc[:, [col]].boxplot().set(title='Диаграмма размаха значений переменной {col_name}',
                                         ylabel=col_name) #  строим диаграмму размаха
        plt.show()
    
    return lower_fence, upper_fence

# %% [markdown]
# Функция, которая подбирает оптимальный порог для модели и строит PR-кривую и ROC-кривую. Так же функция сохраняет лучшие метрики F1 и AUC-ROC в список для дальнейшей сводной таблицы.

# %%
def ml_threshold(model, data_list, score_list, auc_roc_score, threshold_list = None):
    '''
    Функция принимает в параметры модель, датасеты, и подбирает оптимальный порог, выводит лучшие метрики метрики, 
    и PR-кривую, ROC-кривую.
    model - модель;
    data_list - список, содержащий датасеты [features_valid, target_valid];
    score_list - список, куда будут сохранены оценки (f1);
    auc_roc_score - список, куда будут сохранены оценки roc-кривой;
    threshold_list - список, сохраняющий лучшее значение порога.
    
    '''
    predictions = model.predict_proba(data_list[0])# найдем вероятности классов
    probabilities_one_valid = predictions[:, 1] # вероятность положительного класса
    best_score = 0
    best_threshold = 0
    
    # цикл на перебор порога и вывод результатов на экран
    print('Статистика модели')
    for threshold in np.arange(0, 0.9, 0.02):
        predicted_valid = probabilities_one_valid > threshold # находим вероятности больше порога
        # вычисляем метрики
        precision = precision_score(data_list[1], predicted_valid)
        recall = recall_score(data_list[1], predicted_valid)
        result = f1_score(data_list[1], predicted_valid)
        print('Порог = {:.2f} | Точность = {:.3f}, Полнота = {:.3f} | F1-мера = {:.3f}'.format(
             threshold, precision, recall, result))
        if best_score < result:
            best_score = result
            best_threshold = threshold
    
    roc_auc = roc_auc_score(data_list[1], predictions[:, 1])
    # вывод оценок
    print()
    print('Лучшие оценки модели')
    print(f'F1: {best_score:.4}')
    print(f'AUC-ROC: {roc_auc:.4}') 
    print('Лучшее значение порога:', round(best_threshold, 2)) 
    print('_' * 40)
    print()
    print()
    
    # дополнение списка оценок
    score_list.append(round(best_score, 4))
    auc_roc_score.append(round(roc_auc, 4))
    
    if threshold_list is not None:
        threshold_list.append(round(best_threshold, 4))
        
    # построим PR-кривую
    precision, recall, thresholds = precision_recall_curve(
        data_list[1], predictions[:, 1]
    )    
    plt.figure(figsize=(10, 10))
    plt.step(recall, precision, where='post')
    plt.xlabel('Recall')
    plt.ylabel('Precision')
    plt.ylim([0.0, 1.05])
    plt.xlim([0.0, 1.0])
    plt.title('PR-кривая')
     
    # построим ROC-кривую
    fpr, tpr, thresholds = roc_curve(data_list[1], predictions[:, 1])
    plt.figure(figsize=(10, 10))
    plt.plot(fpr, tpr, linestyle='-')
    plt.plot([0, 1], [0, 1], linestyle='--')
    plt.xlim([0.0, 1.0])
    plt.ylim([0.0, 1.0])
    plt.xlabel('False Positive Rate')
    plt.ylabel('True Positive Rate')
    plt.title('ROC-кривая')
   
    plt.show()

# %% [markdown]
# ### Обзор данных

# %% [markdown]
# #### Загрузка данных

# %% [markdown]
# Загрузим датасет из `/datasets/Churn.csv` в датафрейм `data`.

# %%
# чтение файла с данными и сохранение в data
try:
    data = pd.read_csv('/datasets/Churn.csv')
except:
    data = pd.read_csv('https://code.s3.yandex.net/datasets/Churn.csv')

# %% [markdown]
# #### Изучение общей информации о данных

# %% [markdown]
# Выведем первые 20 строчек датафрейма data на экран.

# %%
# получение первых 20 строк таблицы data
data.head(20)
# Out:
#     RowNumber  CustomerId    Surname  CreditScore Geography  Gender  Age  \
# 0           1    15634602   Hargrave          619    France  Female   42
# 1           2    15647311       Hill          608     Spain  Female   41
# 2           3    15619304       Onio          502    France  Female   42
# 3           4    15701354       Boni          699    France  Female   39
# 4           5    15737888   Mitchell          850     Spain  Female   43
# 5           6    15574012        Chu          645     Spain    Male   44
# 6           7    15592531   Bartlett          822    France    Male   50
# 7           8    15656148     Obinna          376   Germany  Female   29
# 8           9    15792365         He          501    France    Male   44
# 9          10    15592389         H?          684    France    Male   27
# 10         11    15767821     Bearce          528    France    Male   31
# 11         12    15737173    Andrews          497     Spain    Male   24
# ...

# %% [markdown]
# На первый взгляд данные хорошо подготовлены.
#
# Выведем основную информацию о датафрейме.

# %%
# получение общей информации о данных в таблице data
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   RowNumber        10000 non-null  int64
#  1   CustomerId       10000 non-null  int64
#  2   Surname          10000 non-null  object
#  3   CreditScore      10000 non-null  int64
#  4   Geography        10000 non-null  object
#  5   Gender           10000 non-null  object
#  6   Age              10000 non-null  int64
#  7   Tenure           9091 non-null   float64
#  8   Balance          10000 non-null  float64
#  9   NumOfProducts    10000 non-null  int64
#  10  HasCrCard        10000 non-null  int64
#  11  IsActiveMember   10000 non-null  int64
#  12  EstimatedSalary  10000 non-null  float64
#  13  Exited           10000 non-null  int64
# dtypes: float64(3), int64(8), object(3)
# memory usage: 1.1+ MB

# %% [markdown]
# Итак, в таблице 14 столбцов. Есть категориальные признаки, например `Gender`, `Geography`.
#
# Видим, что в столбце `Tenure` есть пропуски. Так же названия столбцов не соответствуют общепринятым правилам (змеиному ргистру).
# Типы данных соответствуют описанию данных.
#
# Запишем в отдельные переменные признаки и целевой признак. Целевой признак - exited - запишем его в переменную target, все остальные признаки запишем в переменную features.

# %%
# запишем в переменную features признаки
features = data.drop(['Exited'], axis=1)
# запишем в переменную target целевой признак
target = data['Exited']

# %% [markdown]
# Посмотрим основные статистичекие метрики.

# %%
# выводим статистические метрики
features.describe().T
# Out:
#                    count          mean           std          min  \
# RowNumber        10000.0  5.000500e+03   2886.895680         1.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure            9091.0  4.997690e+00      2.894723         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
#
#                          25%           50%           75%          max
# RowNumber            2500.75  5.000500e+03  7.500250e+03     10000.00
# CustomerId       15628528.25  1.569074e+07  1.575323e+07  15815690.00
# ...

# %% [markdown]
# Видим, что есть значительный разброс значений. Следовательно, потребуется масштабирование.

# %% [markdown]
# Выведим характеристики данных в `features`.

# %%
# вызываем функцию для расчета характеристик по данным
dataframe_information(features)
# Out:
#                name   object   na  zero    rate  unique  neg          mean  \
# 0         RowNumber    int64    0     0  0.0000   10000    0  5.000500e+03
# 1        CustomerId    int64    0     0  0.0000   10000    0  1.569094e+07
# 2           Surname   object    0     0  0.0000    2932    0  0.000000e+00
# 3       CreditScore    int64    0     0  0.0000     460    0  6.505288e+02
# 4         Geography   object    0     0  0.0000       3    0  0.000000e+00
# 5            Gender   object    0     0  0.0000       2    0  0.000000e+00
# 6               Age    int64    0     0  0.0000      70    0  3.892180e+01
# 7            Tenure  float64  909   382  0.1291      11    0  4.997690e+00
# 8           Balance  float64    0  3617  0.3617    6382    0  7.648589e+04
# 9     NumOfProducts    int64    0     0  0.0000       4    0  1.530200e+00
# 10        HasCrCard    int64    0  2945  0.2945       2    0  7.055000e-01
# ...

# %% [markdown]
# Видим, что в столбце `Tenure` 909 пропусков. Так же в столбце `Balance` (баланс на счете) 36% - нулевые значения. Отрицательных значений нет. Больше в данных информации о клиентах, которые не ушли, то есть наблюдается дисбаланс классов. Так же наблюдаются выбросы в данных.
#
# Отделим числовые и категориальные признаки. Оставим только те переменные, которые мы будем использовать дальше. Так как столбцы `RowNumber`, `CustomerId`, `Surname` совершенно не влияют на факт ухода клиента, их рассматривать не будем.

# %%
# отделяем числовые признаки
numeric_features = ['CreditScore','Age','Balance','NumOfProducts','EstimatedSalary','Tenure']
numeric_features
# Out:
# ['CreditScore', 'Age', 'Balance', 'NumOfProducts', 'EstimatedSalary', 'Tenure']

# %%
# отделяем категориальные признаки
categorical_features = [col for col in features.columns if (col not in numeric_features 
                                                            and col != 'RowNumber' and col != 'CustomerId'
                                                            and col != 'Surname')] 
categorical_features
# Out:
# ['Geography', 'Gender', 'HasCrCard', 'IsActiveMember']

# %%
data = data.drop(['RowNumber', 'CustomerId', 'Surname'], axis=1)

# %% [markdown]
# Построим общую гистограмму для всех числовых столбцов таблицы, чтобы получить представление о струкуре данных, посмотреть распределение значений.

# %%
# строим гистограммы для всех столбцов
features[numeric_features].hist(bins=50, figsize=(20,15), edgecolor='black')
plt.show()

# %% [markdown]
# Признаки `CreditScore`, `Age`, `Balance` стремятся к нормальному распределнию, однако, у признака `CreditScore` есть странный пик на предельно высоких значениях, а у признака `Balance` есть пик на нулевом значении, как мы уже отмечали выше 36% данных являются нулевое значение. У признака `Age` длинный хвост на высоких значениях. Распределение значений признака `EstimatedSalary` является неожиданным.
#
# Проверим корреляцию между числовыми признаками. Построим матрицу корреляции и матрицу рассеяния.

# %%
# строим матрицу корреляции
features.loc[:,numeric_features].corr()
# Out:
#                  CreditScore       Age   Balance  NumOfProducts  \
# CreditScore         1.000000 -0.003965  0.006268       0.012238
# Age                -0.003965  1.000000  0.028308      -0.030680
# Balance             0.006268  0.028308  1.000000      -0.304180
# NumOfProducts       0.012238 -0.030680 -0.304180       1.000000
# EstimatedSalary    -0.001384 -0.007201  0.012797       0.014204
# Tenure             -0.000062 -0.013134 -0.007911       0.011979
#
#                  EstimatedSalary    Tenure
# CreditScore            -0.001384 -0.000062
# Age                    -0.007201 -0.013134
# Balance                 0.012797 -0.007911
# NumOfProducts           0.014204  0.011979
# EstimatedSalary         1.000000  0.010520
# Tenure                  0.010520  1.000000

# %% [markdown]
# Для наглядности построим тепловую карту матрицы корреляции.

# %%
# строим heatmap матрицы корреляции
sns.heatmap(features.loc[:,numeric_features].corr(),
            xticklabels=features.loc[:,numeric_features].corr().columns,
            yticklabels=features.loc[:,numeric_features].corr().columns)
plt.title('Тепловая карта матрицы корреляции признаков исходных данных')
plt.show()

# %%
# строим матрицу рассеяния
pd.plotting.scatter_matrix(features.loc[:,numeric_features], figsize=(15, 15)) 
plt.show()

# %% [markdown]
# Корреляции между числовыми столбцами не обнаружено, самое больше значение -0,3 это корреляция между Количеством продуктов и балансом на счете. Таким образом, все числовые столбцы можно оставить в датафрейме для обучения модели.

# %% [markdown]
# **Выводы:**
#
# В каждой строке таблицы — данные о поведении клиентов и расторжении договоров с банком.
#
# Предварительно можно утверждать, что, данных достаточно для построения модели, прогнозирующей отток клиентов банка. Нет коррелирующих признаков. Но есть пропуски в столбце `Tenure`, в столбце `Balance` (баланс на счете) много нулевых значений - 36%.
#
# Названия столбцов не соответствуют змеиному регистру, есть выбросы, наблюдается сильный разброс значений в признаках - требуется масштабирование.
#
# Чтобы двигаться дальше, нужно устранить проблемы в данных.

# %% [markdown]
# ## Исследование задачи

# %% [markdown]
# ### Исследование признаков

# %% [markdown]
# Посмотрим размерность датасета.

# %%
# Размер датасета
print(f"В датасете: {features.shape[0]} строк")
# информация о столбцах и типах данных
print(f"В датасете {features.shape[1]} столбцов, из них :")
print(features.dtypes.value_counts())
# Out:
# В датасете: 10000 строк
# В датасете 13 столбцов, из них :
# int64      7
# float64    3
# object     3
# dtype: int64

# %% [markdown]
# Посмотрим статистику по всем столбцам.

# %%
print("Статистика по столбцам:")
features.describe().T
# Out:
# Статистика по столбцам:
#                    count          mean           std          min  \
# RowNumber        10000.0  5.000500e+03   2886.895680         1.00
# CustomerId       10000.0  1.569094e+07  71936.186123  15565701.00
# CreditScore      10000.0  6.505288e+02     96.653299       350.00
# Age              10000.0  3.892180e+01     10.487806        18.00
# Tenure            9091.0  4.997690e+00      2.894723         0.00
# Balance          10000.0  7.648589e+04  62397.405202         0.00
# NumOfProducts    10000.0  1.530200e+00      0.581654         1.00
# HasCrCard        10000.0  7.055000e-01      0.455840         0.00
# IsActiveMember   10000.0  5.151000e-01      0.499797         0.00
# EstimatedSalary  10000.0  1.000902e+05  57510.492818        11.58
#
#                          25%           50%           75%          max
# RowNumber            2500.75  5.000500e+03  7.500250e+03     10000.00
# CustomerId       15628528.25  1.569074e+07  1.575323e+07  15815690.00
# ...

# %% [markdown]
# Посмотрим наличие выбросов в числовых признаках.

# %%
for col in numeric_features:
    search_outliers(features, col)
# Out:
# _____________________________________________
# Интервал фактических значений для переменной CreditScore от 350 до 850
# Интервал нормальных значений для переменной CreditScore от 383.0 до 919.0
# Переменная CreditScore содержит аномальных значений : 0.15%
# _____________________________________________
# Интервал фактических значений для переменной Age от 18 до 92
# Интервал нормальных значений для переменной Age от 14.0 до 62.0
# Переменная Age содержит аномальных значений : 3.59%
# _____________________________________________
# Интервал фактических значений для переменной Balance от 0.0 до 250898.09
# Интервал нормальных значений для переменной Balance от 0 до 319110.6
# Переменная Balance содержит аномальных значений : 0.0%
# Переменная Balance содержит нулевые значения 36.17%
# _____________________________________________
# Интервал фактических значений для переменной NumOfProducts от 1 до 4
# Интервал нормальных значений для переменной NumOfProducts от 0 до 3.5
# ...

# %% [markdown]
# Видим, что аномальные значения есть в признаках: `CreditScore`, `Age`, `NumOfProducts`.

# %% [markdown]
# Посмотрим распределение категориальных признаков.

# %%
for feature in categorical_features:
    print('Значения признака', feature)
    print(features[feature].value_counts())
    print('_' * 40)
    print()
# Out:
# Значения признака Geography
# France     5014
# Germany    2509
# Spain      2477
# Name: Geography, dtype: int64
# ________________________________________
#
# Значения признака Gender
# Male      5457
# Female    4543
# Name: Gender, dtype: int64
# ________________________________________
#
# Значения признака HasCrCard
# 1    7055
# 0    2945
# Name: HasCrCard, dtype: int64
# ________________________________________
#
# Значения признака IsActiveMember
# 1    5151
# 0    4849
# Name: IsActiveMember, dtype: int64
# ________________________________________

# %% [markdown]
# Видим, что есть несколько признаков с несбалансированным весом классов:
# - geography (France больше почти в 2 раза);
# - has_cr_card (клиентов с кредитными картами в 2 раза больше, чем клиентов без кредитных карт).

# %% [markdown]
# Проверим, есть ли пропуски в данных.

# %%
# суммарное количество пропусков в датафрейме features
features.isnull().sum()
# Out:
# RowNumber            0
# CustomerId           0
# Surname              0
# CreditScore          0
# Geography            0
# Gender               0
# Age                  0
# Tenure             909
# Balance              0
# NumOfProducts        0
# HasCrCard            0
# IsActiveMember       0
# EstimatedSalary      0
# dtype: int64

# %% [markdown]
# Видим, что пропуски есть только в признаке `Tenure`.

# %% [markdown]
# Посмотрим на распределение целевого признака.

# %%
# распределение целевого признака
pd.Series(target).value_counts(normalize=True)
# Out:
# 0    0.7963
# 1    0.2037
# Name: Exited, dtype: float64

# %% [markdown]
# Построим график.

# %%
# Bar plot для целевого признака
plt.figure(figsize=(6, 4))
sns.countplot(x=pd.Series(target))
plt.xlabel('Целевой признак')
plt.ylabel('Количество')
plt.title('Распределение целевого признака')
plt.show()

# %% [markdown]
# Наблюдается дисбаланс класса - положительного класса всего 20%.

# %% [markdown]
# **Вывод:**
# 1. Большой разброс значений в признаках - требуется масштабирование.
# 2. Есть выбросыв признаках: `CreditScore` (0.15%), `Age` (3.59%), `NumOfProducts` (0.6%).
# 3. Есть 909 пропусков в признаке `Tenure`.
# 4. В данных дисбаланс классов - объекты положительного класса составляют 20%.

# %% [markdown]
# ### Предобработка данных

# %% [markdown]
# #### Переименование признаков

# %% [markdown]
# Приведем названия всех признаков к змеиному регистру.

# %%
data = data.rename(columns=lambda column: re.sub(r'(?<!^)(?=[A-Z])', '_', column).lower())
data.columns
# Out:
# Index(['credit_score', 'geography', 'gender', 'age', 'tenure', 'balance',
#        'num_of_products', 'has_cr_card', 'is_active_member',
#        'estimated_salary', 'exited'],
#       dtype='object')

# %% [markdown]
# Названия признаков изменены корректно. Изменим названия категориальных и числовых признаков.

# %%
# отделяем числовые признаки
numeric_features = ['credit_score','age','balance','num_of_products','estimated_salary','tenure']
numeric_features
# Out:
# ['credit_score',
#  'age',
#  'balance',
#  'num_of_products',
#  'estimated_salary',
#  'tenure']

# %%
# отделяем категориальные признаки
categorical_features = [col for col in data.columns if (col not in numeric_features 
                                                            and col != 'exited')] 
categorical_features
# Out:
# ['geography', 'gender', 'has_cr_card', 'is_active_member']

# %% [markdown]
# #### Разбиение данных на выборки

# %% [markdown]
# Так как у нас нет скрытой тестовой выборки - сделаем свою. Разделим данные на обучающую, валидационную и тестовую выборки в соотношении 3:1:1.

# %%
# отделим 40% данных для валидационной и тестовой выборок с учётом стратификации
features_train, features_valid_test = train_test_split(
    data, test_size=0.4, stratify = data['exited'], random_state=MY_RANDOM_STATE)

# %%
# отделим 20% данных для тестовой выборки с учётом стратификации
features_valid, features_test = train_test_split(
    features_valid_test, test_size=0.5, stratify = features_valid_test['exited'], random_state=MY_RANDOM_STATE)

# %% [markdown]
# Проверим размерность получившихся выборок, чтобы убедиться, что разделение на 3 выборки прошло корректно.

# %%
print('Обучающая выборка')
print(features_train.shape)
print()
print('Валидационная выборка')
print(features_valid.shape)
print()
print('Тестовая выборка')
print(features_test.shape)
print()
# Out:
# Обучающая выборка
# (6000, 11)
#
# Валидационная выборка
# (2000, 11)
#
# Тестовая выборка
# (2000, 11)

# %% [markdown]
# Размерность выборок получилась 3:1:1, разделение прошло корректно.

# %% [markdown]
# #### Поиск и обработка пропусков

# %% [markdown]
# Посмотрим еще раз на количество пропусков.

# %%
# количество пропусков в процентах
pd.DataFrame(round(features_train.isna().mean()*100,)).style.background_gradient('coolwarm')
# Out:
# <style  type="text/css" >
# #T_684df_row0_col0,#T_684df_row1_col0,#T_684df_row2_col0,#T_684df_row3_col0,#T_684df_row5_col0,#T_684df_row6_col0,#T_684df_row7_col0,#T_684df_row8_col0,#T_684df_row9_col0,#T_684df_row10_col0{
#             background-color:  #3b4cc0;
#             color:  #f1f1f1;
#         }#T_684df_row4_col0{
#             background-color:  #b40426;
#             color:  #f1f1f1;
#         }</style><table id="T_684df_" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >0</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_684df_level0_row0" class="row_heading level0 row0" >credit_score</th>
#                         <td id="T_684df_row0_col0" class="data row0 col0" >0.000000</td>
#             </tr>
#             <tr>
#                         <th id="T_684df_level0_row1" class="row_heading level0 row1" >geography</th>
# ...

# %% [markdown]
# Построим тепловую карту для пропущенных значений.

# %%
colours = ['#000099', '#ffff00'] 
sns.heatmap(features_train.isnull(), cmap=sns.color_palette(colours))
# указываем наименования осей и графика
plt.xlabel('Признаки')
plt.ylabel('Количество записей')
plt.title('Тепловая карта пропущенных значений')
plt.show()

# %% [markdown]
# Пропуски значений есть только в одном признаке - `tenure` - 9% пропусков. Мы не нашли корреляции данного признака с другими, непонятна природа пропусков, возможно, это просто сбой системы. Попробуем заполнить их.
#
# Посмотрим на распределение данного признака.

# %%
# построим гистограмму по столбцу Tenure 
features_train['tenure'].hist(bins=11)
plt.show()

# %%
# посмотрим статистики по столбцу Tenure
features_train['tenure'].describe()
# Out:
# count    5454.000000
# mean        5.029520
# std         2.890325
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         8.000000
# max        10.000000
# Name: tenure, dtype: float64

# %%
# посмотрим значения по столбцу Tenure
features_train['tenure'].value_counts()
# Out:
# 8.0     569
# 2.0     568
# 3.0     562
# 7.0     557
# 1.0     553
# 5.0     548
# 9.0     543
# 4.0     533
# 6.0     531
# 10.0    266
# 0.0     224
# Name: tenure, dtype: int64

# %% [markdown]
# ёЗаменим пропуски статистически устойчивой медианой.

# %%
med = features_train['tenure'].median()
# заполним пропуски медианным значением
features_train['tenure'] = features_train['tenure'].fillna(med)

# %%
# посмотрим повторно гистограмму по столбцу Tenure
features_train['tenure'].hist(bins=11)
plt.show()

# %%
features_train['tenure'].describe()
# Out:
# count    6000.000000
# mean        5.026833
# std         2.755669
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         7.000000
# max        10.000000
# Name: tenure, dtype: float64

# %%
# посмотрим значения по столбцу Tenure
features_train['tenure'].value_counts()
# Out:
# 5.0     1094
# 8.0      569
# 2.0      568
# 3.0      562
# 7.0      557
# 1.0      553
# 9.0      543
# 4.0      533
# 6.0      531
# 10.0     266
# 0.0      224
# Name: tenure, dtype: int64

# %% [markdown]
# Проверим еще раз наличие пропусков.

# %%
# проверим, что в датафрейме отсутствуют пропущенные значения
features_train.isna().sum()
# Out:
# credit_score        0
# geography           0
# gender              0
# age                 0
# tenure              0
# balance             0
# num_of_products     0
# has_cr_card         0
# is_active_member    0
# estimated_salary    0
# exited              0
# dtype: int64

# %% [markdown]
# Пропусков в датафрейме не осталось.

# %% [markdown]
# Заполним таким же образом пропуски в валидационной и тестовой выборках.

# %%
# заполним пропуски медианой
features_valid['tenure'] = features_valid['tenure'].fillna(med)

# %%
# заполним пропуски медианой
features_test['tenure'] = features_test['tenure'].fillna(med)

# %% [markdown]
# #### Поиск дубликатов

# %% [markdown]
# Проверим, нет ли в данных полных строк-дубликатов.

# %%
# проверим, что в датафрейме отсутствуют дубликаты 
features_train.duplicated().sum()
# Out:
# 0

# %% [markdown]
# Явных дубликатов в данных нет.

# %% [markdown]
# #### Изучение выбросов

# %% [markdown]
# - Кредитный рейтинг - `credit_score`. Посмотрим еще раз статистические характеристики признака и его рапределение.

# %%
# выведим статистические характеристики признака
features_train['credit_score'].describe()
# Out:
# count    6000.000000
# mean      650.666833
# std        96.212140
# min       350.000000
# 25%       584.000000
# 50%       652.000000
# 75%       717.000000
# max       850.000000
# Name: credit_score, dtype: float64

# %%
# построим распределение признака
features_train['credit_score'].hist(bins=100) # строим гистограмму
# указываем наименования осей и графика
plt.xlabel('Кредитный рейтинг')
plt.ylabel('Количество клиентов')
plt.title('Гистограмма по значениям кредитного рейтинга')
plt.show()

# %% [markdown]
# Распределение стремится к нормальному, однако, есть пик на высоких значениях - 850. Построим диаграмму размаха.

# %%
search_outliers(features_train, 'credit_score', 'Кредитный рейтинг')
# Out:
# _____________________________________________
# Интервал фактических значений для переменной credit_score от 350 до 850
# Интервал нормальных значений для переменной credit_score от 384.5 до 916.5
# Переменная credit_score содержит аномальных значений : 0.13%
# (384.5, 916.5)

# %% [markdown]
# Ориентировочная граница нормального размаха - от 382 до 850 (максимальное значение). Есть выбросы ниже 382, а так же пик на высоких значениях.

# %% [markdown]
# - Возраст - `age`. Посмотрим статистические характеристики признака и его рапределение.

# %%
# выведим статистические характеристики признака
features_train['age'].describe()
# Out:
# count    6000.000000
# mean       38.844167
# std        10.420236
# min        18.000000
# 25%        32.000000
# 50%        37.000000
# 75%        44.000000
# max        85.000000
# Name: age, dtype: float64

# %%
features_train['age'].value_counts().sort_index().plot.bar(figsize=(20, 6)) # строим возрастающую столбчатую диаграмму
# указываем наименования осей и графика
plt.xlabel('Возраст')
plt.ylabel('Количество клиентов')
plt.title('Диаграмма распределения клиентов по возрастам')
plt.show()

# %% [raw]
# Распределение колокообразное, однако, имеется длинный хвост справа. Построим диаграмму размаха.

# %%
search_outliers(features_train, 'age', 'Возраст')
# Out:
# _____________________________________________
# Интервал фактических значений для переменной age от 18 до 85
# Интервал нормальных значений для переменной age от 14.0 до 62.0
# Переменная age содержит аномальных значений : 3.43%
# (14.0, 62.0)

# %% [markdown]
# Ориентировочная граница нормального размаха - от 18 (минимальное значение) до 62 года.

# %% [markdown]
# - Сколько лет человек является клиентом банка - `tenure`. Посмотрим статистические характеристики признака и его рапределение.

# %%
# выведим статистические характеристики признака
features_train['tenure'].describe()
# Out:
# count    6000.000000
# mean        5.026833
# std         2.755669
# min         0.000000
# 25%         3.000000
# 50%         5.000000
# 75%         7.000000
# max        10.000000
# Name: tenure, dtype: float64

# %%
features_train['tenure'].value_counts().sort_index().plot.bar() # строим возрастающую столбчатую диаграмму
# указываем наименования осей и графика
plt.xlabel('Сколько лет является клиентом банка')
plt.ylabel('Количество клиентов')
plt.title('Диаграмма распределения клиентов по количеству лет сотрудничества с банком')
plt.show()

# %% [markdown]
# Распределение оказалось неожиданным. Построим диаграмму размаха.

# %%
search_outliers(features_train, 'tenure', 'Количество лет сотрудничества клиента с банком')
# Out:
# _____________________________________________
# Интервал фактических значений для переменной tenure от 0.0 до 10.0
# Интервал нормальных значений для переменной tenure от 0 до 13.0
# Переменная tenure содержит аномальных значений : 0.0%
# Переменная tenure содержит нулевые значения 3.73%
# (0, 13.0)

# %% [markdown]
# Ориентировочная граница нормального размаха - от 0 (минимальное значение) до 10 лет (максимальное значение). Выбросов не наблюдается.

# %% [markdown]
# - Баланс на счёте - `balance`. Посмотрим статистические характеристики признака и его рапределение.

# %%
# выведим статистические характеристики признака
features_train['balance'].describe()
# Out:
# count      6000.000000
# mean      76930.371207
# std       62295.625264
# min           0.000000
# 25%           0.000000
# 50%       97405.605000
# 75%      127846.337500
# max      250898.090000
# Name: balance, dtype: float64

# %%
# построим распределение признака
features_train['balance'].hist(bins=100) # строим гистограмму
# указываем наименования осей и графика
plt.xlabel('Баланс на счете')
plt.ylabel('Количество клиентов')
plt.title('Гистограмма по значениям баланса на счете')
plt.show()

# %% [markdown]
# Распределение стремится к нормальному, однако, есть пик на нулевых значениях - больше 2000 клиентов. Построим диаграмму размаха.

# %%
search_outliers(features_train, 'balance', 'Баланс на счете')
# Out:
# _____________________________________________
# Интервал фактических значений для переменной balance от 0.0 до 250898.09
# Интервал нормальных значений для переменной balance от 0 до 319615.84
# Переменная balance содержит аномальных значений : 0.0%
# Переменная balance содержит нулевые значения 35.78%
# (0, 319615.84)

# %% [markdown]
# Ориентировочная граница нормального размаха - от 0 (минимальное значение) до 238387.56 (максимальное значение). Выбросов в данных нет, видим, что медиана стремится к высоким значениям. Так как информации о пике на нулевых значениях нет, оставим эти объекты.

# %% [markdown]
# - Предпологаемая зарплата - `estimated_salary`. Посмотрим статистические характеристики признака и его рапределение.

# %%
# выведим статистические характеристики признака
features_train['estimated_salary'].describe()
# Out:
# count      6000.000000
# mean      99452.541713
# std       57408.169996
# min          11.580000
# 25%       51014.837500
# 50%       99320.335000
# 75%      148628.575000
# max      199992.480000
# Name: estimated_salary, dtype: float64

# %%
# построим распределение признака
features_train['estimated_salary'].hist(bins=100) # строим гистограмму
# указываем наименования осей и графика
plt.xlabel('Предполагаемая зарплата')
plt.ylabel('Количество клиентов')
plt.title('Гистограмма по значениям предполагаемой зарплаты')
plt.show()

# %% [markdown]
# Распределение отлично от предпологаемого нормального. Построим диаграмму размаха.

# %%
search_outliers(features_train, 'estimated_salary', 'Предполагаемая зарплата')
# Out:
# _____________________________________________
# Интервал фактических значений для переменной estimated_salary от 11.58 до 199992.48
# Интервал нормальных значений для переменной estimated_salary от 0 до 295049.18
# Переменная estimated_salary содержит аномальных значений : 0.0%
# (0, 295049.18)

# %% [markdown]
# Выбросов не наблюдается, данные семмитричные, похоже уже предобработанные.

# %% [markdown]
# - Количество продуктов банка, используемых клиентом - `num_of_products`. Посмотрим статистические характеристики признака и его рапределение.

# %%
# выведим статистические характеристики признака
features_train['num_of_products'].describe()
# Out:
# count    6000.000000
# mean        1.527500
# std         0.579338
# min         1.000000
# 25%         1.000000
# 50%         1.000000
# 75%         2.000000
# max         4.000000
# Name: num_of_products, dtype: float64

# %%
features_train['num_of_products'].value_counts().sort_index().plot.bar() # строим возрастающую столбчатую диаграмму
# указываем наименования осей и графика
plt.xlabel('Количество продуктов банка, используемых клиентом')
plt.ylabel('Количество клиентов')
plt.title('Диаграмма распределения клиентов по количеству продуктов, используемых клиентом')
plt.show()

# %%
search_outliers(features_train, 'num_of_products', 'Количество продуктов банка, используемых клиентом')
# Out:
# _____________________________________________
# Интервал фактических значений для переменной num_of_products от 1 до 4
# Интервал нормальных значений для переменной num_of_products от 0 до 3.5
# Переменная num_of_products содержит аномальных значений : 0.55%
# (0, 3.5)

# %% [markdown]
# **Вывод:**
#
# 1. Привели все названия столбцов к общепринятому "змеиному регистру".
# 2. Разбили данные на 3 выборки с учетом стратификации в соотношении 3:1:1: обучающую, валидационнцю и тестовую.
# 3. Нашли и обработали пропущенные значения в столбце `tenure`. Мы не стали удалять пропуски, так как могли потерять данные из класса, в котором итак их мало (клиенты, которые расторгли договор с банком). Было принято решение заменить пропуски медианой.
# 4. Явных дубликатов обнаружено не было.
# 5. В численных признаках были обнаружены выбросы: в `credit_score`, `age`, `num_of_products`.
# 6. Были обнаружены "странности в распределениях" признаков:
# - был обнаружен пик нулевых значений признака `balance`, который было решено оставить;
# - так же обнаружен пик на предельно высоких значениях признака `credit_score`, который также был оставлен ввиду отсутствия информации.
# 7. Среди категориальных признаков был обнаружен дисбаланс классов:
# - `geography` (France больше почти в 2 раза);
# - `has_cr_card` (клиентов с кредитными картами в 2 раза больше, чем клиентов без кредитных карт).
# 8. Целевой признак так же несбалансирован: положительных значений в выборке всего 20%.

# %% [markdown]
# ### Выделение признаков и целевого признака

# %% [markdown]
# Запишем в отдельные переменные признаки и целевой признак для трех выборок. Целевой признак - exited - запишем его в переменную target, все остальные признаки запишем в переменную features.

# %%
# запишем в переменную target целевой признак (обучающая выборка)
target_train = features_train['exited']
# запишем в переменную features признаки (обучающая выборка)
features_train = features_train.drop(['exited'], axis=1)

# %%
# запишем в переменную target целевой признак (валидационная выборка)
target_valid = features_valid['exited']
# запишем в переменную features признаки (валидационная выборка)
features_valid = features_valid.drop(['exited'], axis=1)

# %%
# запишем в переменную target целевой признак (тестовая выборка)
target_test = features_test['exited']
# запишем в переменную features признаки (тестовая выборка)
features_test = features_test.drop(['exited'], axis=1)

# %% [markdown]
# Проверим размерность.

# %%
print(features_train.shape)
print(target_train.shape)
print()
print(features_valid.shape)
print(target_valid.shape)
print()
print(features_test.shape)
print(target_test.shape)
# Out:
# (6000, 10)
# (6000,)
#
# (2000, 10)
# (2000,)
#
# (2000, 10)
# (2000,)

# %% [markdown]
# ### Подготовка признаков

# %% [markdown]
# #### Прямое кодирование

# %% [markdown]
# Преобразуем категориальные признаки в численные с помощью техники прямого кодирования, или отображения (One-Hot Encoding, OHE). Используем эту технику, так как она работает со всеми моделями, в том числе и логистической регрессией. Чтобы не попасть в дамми-ловушку, один из новых признаков будем удалять.

# %%
ohe_features = ['geography', 'gender']
ohe_encoder = OneHotEncoder(drop='first', sparse=False)

# %%
# применим one hot encoding к датафрейму, избежав "ловушку фиктивных признаков"
train_temp = ohe_encoder.fit_transform(features_train[ohe_features]) # обучили на трейне и сразу к нему применили
features_train[ohe_encoder.get_feature_names()] = train_temp # вписали новые признаки
features_train.drop(ohe_features, axis=1, inplace=True) # удалили старые признаки
features_train.head()
# Out:
#       credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 2515           564   40     4.0       0.00                1            1
# 4669           443   50     3.0  117206.30                1            1
# 5568           693   38     5.0  198338.77                2            1
# 6237           630   28     5.0       0.00                2            1
# 2386           541   46     4.0  124547.13                2            1
#
#       is_active_member  estimated_salary  x0_Germany  x0_Spain  x1_Male
# 2515                 0          85455.62         0.0       0.0      1.0
# 4669                 0          42840.18         1.0       0.0      1.0
# 5568                 1          14278.18         0.0       0.0      1.0
# 6237                 1         133267.78         0.0       0.0      0.0
# 2386                 0          94499.06         0.0       0.0      1.0

# %%
# применим one hot encoding к датафрейму, избежав "ловушку фиктивных признаков"
valid_temp = ohe_encoder.transform(features_valid[ohe_features]) # обученный энкодер применили к валид. выборке
features_valid[ohe_encoder.get_feature_names()] = valid_temp # добавляем в валид. выборку новые признаки
features_valid.drop(ohe_features, axis=1, inplace=True) # удаляем старые признаки
features_valid.head()
# Out:
#       credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 1912           687   29     4.0   78939.15                1            1
# 2968           696   36     5.0       0.00                2            1
# 2561           655   34     1.0  116114.93                1            1
# 1932           655   56     5.0       0.00                2            1
# 9044           560   47     1.0       0.00                1            0
#
#       is_active_member  estimated_salary  x0_Germany  x0_Spain  x1_Male
# 1912                 0         122134.56         1.0       0.0      0.0
# 2968                 1          82298.59         0.0       1.0      0.0
# 2561                 1          49492.15         0.0       1.0      1.0
# 1932                 1          41782.70         0.0       1.0      0.0
# 9044                 0         128882.66         0.0       1.0      1.0

# %%
# применим one hot encoding к датафрейму, избежав "ловушку фиктивных признаков"
test_temp = ohe_encoder.transform(features_test[ohe_features]) # обученный энкодер применили к тест. выборке
features_test[ohe_encoder.get_feature_names()] = test_temp # вписали новые признаки
features_test.drop(ohe_features, axis=1, inplace=True) # удалили старые признаки
features_test.head()
# Out:
#       credit_score  age  tenure    balance  num_of_products  has_cr_card  \
# 4835           561   34     4.0   85141.79                2            1
# 2372           737   43     1.0  125537.38                1            1
# 8378           614   37     6.0   96340.81                2            1
# 2891           613   30     5.0  131563.88                2            1
# 4337           850   38     5.0       0.00                2            1
#
#       is_active_member  estimated_salary  x0_Germany  x0_Spain  x1_Male
# 4835                 1          29217.37         0.0       1.0      1.0
# 2372                 0         138510.01         1.0       0.0      0.0
# 8378                 1         139377.24         1.0       0.0      0.0
# 2891                 0         170638.98         1.0       0.0      0.0
# 4337                 0          16491.64         0.0       0.0      1.0

# %% [markdown]
# Проверим размерность.

# %%
print('Размерность обучающей выборки')
print(features_train.shape)
print()
print('Размерность валидационной выборки')
print(features_valid.shape)
print()
print('Размерность тестовой выборки')
print(features_test.shape)
# Out:
# Размерность обучающей выборки
# (6000, 11)
#
# Размерность валидационной выборки
# (2000, 11)
#
# Размерность тестовой выборки
# (2000, 11)

# %% [markdown]
# Кодирование прошло корректно.

# %% [markdown]
# #### Масштабирование признаков

# %% [markdown]
# Как мы уже выяснили раннее нам потребуется масштабирование признаков. Для этого проведем стандартизацию данных с помощью StandardScaler.
#
# Для начала определим числовые признаки.

# %%
# нормируем числовые данные, используя StandardScaler
scaler = StandardScaler()
scaler.fit(features_train[numeric_features])
features_train[numeric_features] = scaler.transform(features_train[numeric_features])
features_test[numeric_features] = scaler.transform(features_test[numeric_features])
features_valid[numeric_features] = scaler.transform(features_valid[numeric_features])

# %%
features_valid[numeric_features].describe()
# Out:
#        credit_score          age      balance  num_of_products  \
# count   2000.000000  2000.000000  2000.000000      2000.000000
# mean      -0.007857     0.016012    -0.006992         0.012947
# std        1.022772     0.992377     1.001477         1.015335
# min       -2.948593    -2.000521    -1.235027        -0.910597
# 25%       -0.724156    -0.656870    -1.235027        -0.910597
# 50%        0.003463    -0.129007     0.338098        -0.910597
# 75%        0.720688     0.494832     0.808792         0.815653
# max        2.071982     4.717737     2.592006         4.268155
#
#        estimated_salary       tenure
# count       2000.000000  2000.000000
# mean           0.010861    -0.019356
# std            1.007077     1.006642
# min           -1.730023    -1.824331
# 25%           -0.860315    -0.735575
# 50%            0.000764    -0.009738
# 75%            0.881986     0.716099
# max            1.748252     1.804854

# %% [markdown]
# **Вывод:**
# 1. Преобразовали категориальные признаки в численные с помощью техники прямого кодирования, избегая при этом дамми-ловушки, используя параметр 'drop_first=True'.
# 2. Провели стандартизацию числовых признаков (`credit_score`, `age`, `balance`, `num_of_products`, `estimated_salary`, `tenure`) с помощью StandardScaler.

# %% [markdown]
# ### Обучение модели

# %% [markdown]
# Для начала построим модели на несбалансированных данных.

# %% [markdown]
# #### Логистическая регрессия

# %% [markdown]
# Обучим модель логистической регрессии и посчитаем метрики - F1-меру и ROC-кривую (кривая ошибок), на валидационной выборке.

# %%
# обучим модель логистической регрессии и посчитаем метрики на валидационной выборке
model_lr = LogisticRegression(solver='liblinear', random_state=MY_RANDOM_STATE)
model_lr.fit(features_train, target_train)
predicted_valid = model_lr.predict(features_valid)
predictions = model_lr.predict_proba(features_valid)# найдем вероятности классов

print("F1 модели на валидационной выборке:", f1_score(target_valid, predicted_valid))
print("AUC-ROC модели на валидационной выборке:", roc_auc_score(target_valid, predictions[:, 1]))
# Out:
# F1 модели на валидационной выборке: 0.2934782608695652
# AUC-ROC модели на валидационной выборке: 0.7401622080993202

# %% [markdown]
# Изменим порог и построим PR-кривую и ROC-кривую.

# %%
# создадим список для сохранения F1-метрики, AUC_ROC, порог моделей на неочищенных от выбросов данных
f1_score_list = []
auc_roc_score_list = []
threshold_list = []

# %%
# вызовем функцию для подбора порога и построения PR-кривой и ROC-кривой
ml_threshold(model_lr, [features_valid, target_valid], f1_score_list, 
             auc_roc_score_list, threshold_list)
# Out:
# Статистика модели
# Порог = 0.00 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.02 | Точность = 0.205, Полнота = 0.998 | F1-мера = 0.340
# Порог = 0.04 | Точность = 0.217, Полнота = 0.985 | F1-мера = 0.355
# Порог = 0.06 | Точность = 0.233, Полнота = 0.956 | F1-мера = 0.374
# Порог = 0.08 | Точность = 0.253, Полнота = 0.926 | F1-мера = 0.398
# Порог = 0.10 | Точность = 0.268, Полнота = 0.892 | F1-мера = 0.412
# Порог = 0.12 | Точность = 0.284, Полнота = 0.853 | F1-мера = 0.426
# Порог = 0.14 | Точность = 0.304, Полнота = 0.814 | F1-мера = 0.443
# Порог = 0.16 | Точность = 0.320, Полнота = 0.767 | F1-мера = 0.452
# Порог = 0.18 | Точность = 0.340, Полнота = 0.730 | F1-мера = 0.464
# Порог = 0.20 | Точность = 0.359, Полнота = 0.686 | F1-мера = 0.472
# Порог = 0.22 | Точность = 0.368, Полнота = 0.625 | F1-мера = 0.463
# Порог = 0.24 | Точность = 0.382, Полнота = 0.571 | F1-мера = 0.458
# Порог = 0.26 | Точность = 0.395, Полнота = 0.532 | F1-мера = 0.453
# ...

# %% [markdown]
# #### Дерево решений

# %% [markdown]
# Обучим модели дерево решений, при этом меняя гиперпараметр  - `max_depth` - глубина дерева. Переберем значения от 1 до 15.

# %%
best_model_dt = None # переменная для лучшей модели (дерево решение)
best_f1_dt = 0 # переменная для f1 лучшей модели (дерево решение)
best_roc_auc_dt = 0 # переменная для ROC AUC лучшей модели (дерево решение)
best_depth_dt = 0 # переменная для max_depth лучшей модели (дерево решение)
max_depth_list_dt = [] # список перебранных значений для параметра max_depth
f1_list_dt = [] # список посчитанных f1 для всех вариантов модели
roc_auc_list_dt = [] # список посчитанных ROC AUC для всех вариантов модели
# перебираем глубину дерева от 1 до 15
for depth in range(1, 16):
    # создадим модель с параметром, задаваемым в цикле
    model = DecisionTreeClassifier(max_depth=depth, random_state=MY_RANDOM_STATE)
    model.fit(features_train,target_train) # обучение модели на тренировочной выборке
    predicted_valid = model.predict(features_valid) # предсказание на валидационной выборке
    f1 = f1_score(target_valid, predicted_valid) # высчитываем f1
    predictions = model.predict_proba(features_valid)# найдем вероятности классов
    roc_auc =  roc_auc_score(target_valid, predictions[:, 1]) # высчитываем ROC AUC
    # запишем параметры в список
    max_depth_list_dt.append(depth)
    f1_list_dt.append(f1)
    roc_auc_list_dt.append(roc_auc)
    # найдем лучшую модель
    if f1 > best_f1_dt:
        best_model_dt = model # сохраняем наилучшую модель
        best_f1_dt = f1 # сохраняем f1 для наилучшей модели
        best_roc_auc_dt = roc_auc # сохраняем roc_auc для наилучшей модели
        best_depth_dt = depth # сохраняем значение глубины дерева для наилучшей модели

print("F1 наилучшей модели на валидационной выборке:", best_f1_dt, "AUC-ROC:", best_roc_auc_dt, "Глубина дерева:", best_depth_dt)
# Out:
# F1 наилучшей модели на валидационной выборке: 0.5509325681492109 AUC-ROC: 0.819678201054291 Глубина дерева: 7

# %% [markdown]
# Лучшие метрики достигаются при максимальной глубине - 7.
#
# Посмотрим на графике, как изменяется F1 и AUC-ROC при изменении гиперпараметра.

# %%
# построим график зависимости качества от параметров
plt.plot(max_depth_list_dt, f1_list_dt, label="F1")
plt.plot(max_depth_list_dt, roc_auc_list_dt, label="AUC-ROC")
# укажем наименование графика и осей
plt.xlabel('Глубина дерева (max_depth)')
plt.ylabel('Метрики')
plt.title('Зависимость качества от гиперпараметров')
# устанавливаем частоту меток по оси х
plt.xticks(np.arange(min(max_depth_list_dt), max(max_depth_list_dt)+1, 1))
plt.grid(True)
plt.legend()
plt.show()

# %% [markdown]
# Изменим порог и построим PR-кривую и ROC-кривую.

# %%
# вызовем функцию для подбора порога и построения PR-кривой и ROC-кривой
ml_threshold(best_model_dt, 
             [features_valid, target_valid], 
             f1_score_list, 
             auc_roc_score_list,
             threshold_list)
# Out:
# Статистика модели
# Порог = 0.00 | Точность = 0.207, Полнота = 0.983 | F1-мера = 0.342
# Порог = 0.02 | Точность = 0.243, Полнота = 0.975 | F1-мера = 0.389
# Порог = 0.04 | Точность = 0.245, Полнота = 0.975 | F1-мера = 0.391
# Порог = 0.06 | Точность = 0.284, Полнота = 0.909 | F1-мера = 0.433
# Порог = 0.08 | Точность = 0.351, Полнота = 0.848 | F1-мера = 0.496
# Порог = 0.10 | Точность = 0.398, Полнота = 0.784 | F1-мера = 0.528
# Порог = 0.12 | Точность = 0.403, Полнота = 0.784 | F1-мера = 0.532
# Порог = 0.14 | Точность = 0.403, Полнота = 0.784 | F1-мера = 0.532
# Порог = 0.16 | Точность = 0.419, Полнота = 0.770 | F1-мера = 0.543
# Порог = 0.18 | Точность = 0.445, Полнота = 0.733 | F1-мера = 0.554
# Порог = 0.20 | Точность = 0.452, Полнота = 0.733 | F1-мера = 0.559
# Порог = 0.22 | Точность = 0.480, Полнота = 0.723 | F1-мера = 0.577
# Порог = 0.24 | Точность = 0.480, Полнота = 0.723 | F1-мера = 0.577
# Порог = 0.26 | Точность = 0.505, Полнота = 0.610 | F1-мера = 0.553
# ...

# %% [markdown]
# Изменение порога не дало результатов: лучшие метрики получаются при значении порога 0.5.

# %% [markdown]
# #### Случайный лес

# %% [markdown]
# Подберем оптимальные гиперпараметры для модели случайного леса, будем менять гиперпараметры следующим образом:
#     - с количеством деревьев: от 10 до 100 с шагом 10 (n_estimators),
#     - с максимальной глубиной от 1 до 15 (max_depth).

# %%
model_rf_best = None # переменная для лучшей модели (случайный лес)
best_result_rf = 0 # переменная для f1 лучшей модели (случайный лес)
best_roc_auc = 0 # переменная для roc_auc лучшей модели (случайный лес)
best_est_rf = 0 # переменная для n_estimators лучшей модели (случайный лес)
best_depth_rf = 0 # переменная для max_depth лучшей модели (случайный лес)
depth_list_rf = [] # список перебранных значений для параметра max_depth
estimator_list_rf = [] # список перебранных значений для параметра n_estimators
score_list_rf = [] # список посчитанных f1 для всех вариантов модели
# перебираем количество деревьев от 10 до 100 с шагом 10
for est in range(10, 101, 10):
    # перебираем глубину дерева от 1 до 15
    for depth in tqdm(range (1, 16)):
        # создадим модель с параметром задаваемым в цикле
        model = RandomForestClassifier(random_state=MY_RANDOM_STATE,n_estimators=est,max_depth=depth)
        model.fit(features_train,target_train) # обучение модели на тренировочной выборке
        predicted_valid = model.predict(features_valid) # предсказание на валидационной выборке
        result = f1_score(target_valid, predicted_valid) # высчитываем f1
        predictions = model.predict_proba(features_valid)# найдем вероятности классов
        roc_auc =  roc_auc_score(target_valid, predictions[:, 1]) # высчитываем ROC AUC
        # запишем параметры в списки
        depth_list_rf.append(depth)
        estimator_list_rf.append(est)
        score_list_rf.append(result)
        # найдем лучшую модель
        if result > best_result_rf:
            model_rf_best = model # сохраняем наилучшую модель
            best_result_rf = result # сохраняем f1 для наилучшей модели
            best_roc_auc = roc_auc # сохраняем roc_auc для наилучшей модели
            best_est_rf = est # сохраняем значение количества деревьев для наилучшей модели
            best_depth_rf = depth # сохраняем значение глубины дерева для наилучшей модели

print("F1 наилучшей модели:", best_result_rf, "AUC-ROC:", best_roc_auc,
      "Количество деревьев:", best_est_rf, "Максимальная глубина:", best_depth_rf)
# Out:
# ...
# 100%|██████████| 15/15 [00:08<00:00,  1.78it/s]
# F1 наилучшей модели: 0.5683890577507599 AUC-ROC: 0.8352085180805991 Количество деревьев: 60 Максимальная глубина: 13

# %% [markdown]
# Посмотрим на тепловой карте, как изменяется F1 в зависимости от гиперпараметров.

# %%
# создадим датафрейм из списков с данными по работе модели
dict_rf_valid = ({'depth': depth_list_rf, 
                      'n_estimators': estimator_list_rf, 
                      'accuracy': score_list_rf})
df_rf_valid = pd.DataFrame(dict_rf_valid)
df_rf_valid = df_rf_valid.groupby(['depth', 'n_estimators'])['accuracy'].sum()
df_rf_valid = df_rf_valid.unstack('n_estimators')
# строим тепловую карту, показывающую зависимость качества от max_depth и n_estimators
sns.heatmap(df_rf_valid,
                xticklabels=df_rf_valid.columns,
                yticklabels=df_rf_valid.index,
                cmap='RdYlGn')
# указываем наименования осей и графика
plt.xlabel('Количество деревьев (n_estimators)')
plt.ylabel('Глубина дерева (max_depth)')
plt.title('Тепловая карта качества модели по глубине дерева и количеству деревьев')
plt.show()

# %% [markdown]
# Мы подобрали наилучшие гиперпараметры, теперь изменим порог и построим PR-кривую и ROC-кривую.

# %%
# вызовем функцию для подбора порога и построения PR-кривой и ROC-кривой
ml_threshold(model_rf_best, [features_valid, target_valid], f1_score_list, auc_roc_score_list, threshold_list)
# Out:
# Статистика модели
# Порог = 0.00 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.02 | Точность = 0.232, Полнота = 0.980 | F1-мера = 0.375
# Порог = 0.04 | Точность = 0.255, Полнота = 0.966 | F1-мера = 0.403
# Порог = 0.06 | Точность = 0.277, Полнота = 0.934 | F1-мера = 0.427
# Порог = 0.08 | Точность = 0.299, Полнота = 0.917 | F1-мера = 0.451
# Порог = 0.10 | Точность = 0.326, Полнота = 0.890 | F1-мера = 0.477
# Порог = 0.12 | Точность = 0.352, Полнота = 0.865 | F1-мера = 0.500
# Порог = 0.14 | Точность = 0.376, Полнота = 0.836 | F1-мера = 0.519
# Порог = 0.16 | Точность = 0.400, Полнота = 0.801 | F1-мера = 0.533
# Порог = 0.18 | Точность = 0.426, Полнота = 0.779 | F1-мера = 0.551
# Порог = 0.20 | Точность = 0.446, Полнота = 0.750 | F1-мера = 0.559
# Порог = 0.22 | Точность = 0.458, Полнота = 0.713 | F1-мера = 0.558
# Порог = 0.24 | Точность = 0.484, Полнота = 0.686 | F1-мера = 0.567
# Порог = 0.26 | Точность = 0.507, Полнота = 0.654 | F1-мера = 0.571
# ...

# %% [markdown]
# Изменение порога улучшило наши результаты - самые лучшие результаты достигаются при пороге 0.4.

# %% [markdown]
# **Выводы:**
#
# 1. Обучили модели и посчитали метрики:
# - логистическая регрессия: F1 =  0.34, AUC-ROC = 0.74;
# - дерево решений: F1 = 0.55, AUC-ROC = 0.84 (максимальная глубина = 7);
# - случайный лес: F1 = 0.57, AUC-ROC = 0.84 (максимальная глубина = 10, количество деревьев = 30);
# 2. Подобрали оптимальный порог для моделей и посчитали метрики:
# - логистическая регрессия: F1 = 0.47, AUC-ROC = 0.67 при пороге = 0.26;
# - дерево решений: F1 = 0.56, AUC-ROC = 0.83 при пороге = 0.22 (максимальная глубина = 7);
# - случайный лес: F1 = 0.58, AUC-ROC = 0.84 при пороге = 0.48 (максимальная глубина = 15, количество деревьев = 100).
# 3. Таким образом, лучшие метрики показывает модель случайного леса с гиперпараметрами максимальная глубина = 15, количество деревьев = 100 при значении порога 0.48: F1 = 0.58, AUC-ROC = 0.84.
# 4. Сводная таблица по метрикам построенных моделей:

# %%
# сформируем сводную таблицу 
model_names = ['LogisticRegression', 'DecisionTreeClassifier', 'RandomForestClassifier']
score_table_unbalanced = pd.DataFrame(
    {'Модель': model_names, 
     'Несбалансированные данные (F1)': f1_score_list, 
     'Несбалансированные данные (AUC-ROC)': auc_roc_score_list,
     'Оптимальный порог': threshold_list
    }
)               
score_table_unbalanced
# Out:
#                    Модель  Несбалансированные данные (F1)  \
# 0      LogisticRegression                          0.4718
# 1  DecisionTreeClassifier                          0.5773
# 2  RandomForestClassifier                          0.5879
#
#    Несбалансированные данные (AUC-ROC)  Оптимальный порог
# 0                               0.7402               0.20
# 1                               0.8197               0.22
# 2                               0.8352               0.40

# %% [markdown]
# ## Борьба с дисбалансом

# %% [markdown]
# Как уже было выяснено, в наших данных наблюдается значительный дисбаланс: положительных значений в выборке всего 25%. Изучим разные методы борьбы с дисбалансом классов и выберем оптимальную модель и оптимальный метод корректировки дисбаланса классов.

# %% [markdown]
# ### Взвешивание классов

# %% [markdown]
# Используем параметр class_weight, чтобы придать объектам редкого класса больший вес.

# %% [markdown]
# #### Логистическая регрессия

# %%
# рассчитаем модель логистической регреммии с параметром class_weight = 'balanced'
model_lr_balanced = LogisticRegression(random_state=MY_RANDOM_STATE, solver='liblinear',class_weight = 'balanced')
model_lr_balanced.fit(features_train, target_train)
predicted_valid = model_lr_balanced.predict(features_valid)
predictions = model_lr_balanced.predict_proba(features_valid)# найдем вероятности классов
print("F1:", f1_score(target_valid, predicted_valid))
print("ROC_auc:", roc_auc_score(target_valid, predictions[:, 1]))
# Out:
# F1: 0.4727272727272727
# ROC_auc: 0.7426332027785989

# %% [markdown]
# Найдем оптимальный порог классификации для логистической регрессии. Переберем значения порогов от 0 до 0.9 с шагом 0.02 и найдем для каждого значения метрики: точность, полноту, F1-меру и AUC-ROC. Построим PR-кривую и ROC-кривую.

# %%
# создадим список для сохранения F1-метрики и AUC_ROC
f1_score_list_balanced = []
auc_roc_score_list_balanced = []
threshold_list_balanced = []

# %%
# вызовем функцию для подбора порога и построения PR-кривой и ROC-кривой
ml_threshold(model_lr_balanced, 
             [features_valid, target_valid], 
             f1_score_list_balanced, 
             auc_roc_score_list_balanced,
             threshold_list_balanced)
# Out:
# Статистика модели
# Порог = 0.00 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.02 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.04 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.06 | Точность = 0.204, Полнота = 0.998 | F1-мера = 0.339
# Порог = 0.08 | Точность = 0.206, Полнота = 0.998 | F1-мера = 0.342
# Порог = 0.10 | Точность = 0.210, Полнота = 0.995 | F1-мера = 0.346
# Порог = 0.12 | Точность = 0.213, Полнота = 0.993 | F1-мера = 0.351
# Порог = 0.14 | Точность = 0.218, Полнота = 0.985 | F1-мера = 0.357
# Порог = 0.16 | Точность = 0.225, Полнота = 0.983 | F1-мера = 0.366
# Порог = 0.18 | Точность = 0.229, Полнота = 0.968 | F1-мера = 0.370
# Порог = 0.20 | Точность = 0.234, Полнота = 0.953 | F1-мера = 0.376
# Порог = 0.22 | Точность = 0.242, Полнота = 0.946 | F1-мера = 0.385
# Порог = 0.24 | Точность = 0.249, Полнота = 0.936 | F1-мера = 0.393
# Порог = 0.26 | Точность = 0.254, Полнота = 0.914 | F1-мера = 0.397
# ...

# %% [markdown]
# Наилучшие значения метрик достигаются при пороге = 0.54.

# %% [markdown]
# #### Дерево решений

# %% [markdown]
# Обучим модели дерево решений, при этом меняя гиперпараметр - max_depth - глубина дерева. Переберем значения от 1 до 15.

# %%
model_dt_balanced = None # переменная для лучшей модели (дерево решение)
best_f1_dt = 0 # переменная для f1 лучшей модели (дерево решение)
best_roc_auc_dt = 0 # переменная для ROC AUC лучшей модели (дерево решение)
best_depth_dt_balanced = 0 # переменная для max_depth лучшей модели (дерево решение)
# перебираем глубину дерева от 1 до 15
for depth in range(1, 16):
    # создадим модель с параметром, задаваемым в цикле
    model = DecisionTreeClassifier(max_depth=depth, class_weight = 'balanced', random_state=MY_RANDOM_STATE)
    model.fit(features_train,target_train) # обучение модели на тренировочной выборке
    predicted_valid = model.predict(features_valid) # предсказание на валидационной выборке
    f1 = f1_score(target_valid, predicted_valid) # высчитываем accuracy
    predictions = model.predict_proba(features_valid)# найдем вероятности классов
    roc_auc =  roc_auc_score(target_valid, predictions[:, 1]) # высчитываем ROC AUC
    # запишем параметры в список
    max_depth_list_dt.append(depth)
    f1_list_dt.append(f1)
    roc_auc_list_dt.append(roc_auc)
    # найдем лучшую модель
    if f1 > best_f1_dt:
        model_dt_balanced = model # сохраняем наилучшую модель
        best_f1_dt = f1 # сохраняем f1 для наилучшей модели
        best_roc_auc_dt = roc_auc # сохраняем f1 для наилучшей модели
        best_depth_dt_balanced = depth # сохраняем значение глубины дерева для наилучшей модели

print("F1 наилучшей модели на валидационной выборке:", best_f1_dt, "AUC-ROC:", best_roc_auc_dt, "Глубина дерева:", best_depth_dt_balanced)
# Out:
# F1 наилучшей модели на валидационной выборке: 0.5714285714285714 AUC-ROC: 0.8274668378657996 Глубина дерева: 5

# %% [markdown]
# Изменим порог и построим PR-кривую и ROC-кривую.

# %%
# вызовем функцию для подбора порога и построения PR-кривой и ROC-кривой
ml_threshold(model_dt_balanced, 
             [features_valid, target_valid], 
             f1_score_list_balanced, 
             auc_roc_score_list_balanced,
             threshold_list_balanced)
# Out:
# Статистика модели
# Порог = 0.00 | Точность = 0.205, Полнота = 1.000 | F1-мера = 0.340
# Порог = 0.02 | Точность = 0.205, Полнота = 1.000 | F1-мера = 0.340
# Порог = 0.04 | Точность = 0.230, Полнота = 0.998 | F1-мера = 0.374
# Порог = 0.06 | Точность = 0.233, Полнота = 0.995 | F1-мера = 0.378
# Порог = 0.08 | Точность = 0.233, Полнота = 0.995 | F1-мера = 0.378
# Порог = 0.10 | Точность = 0.233, Полнота = 0.995 | F1-мера = 0.378
# Порог = 0.12 | Точность = 0.254, Полнота = 0.971 | F1-мера = 0.403
# Порог = 0.14 | Точность = 0.254, Полнота = 0.971 | F1-мера = 0.403
# Порог = 0.16 | Точность = 0.279, Полнота = 0.936 | F1-мера = 0.430
# Порог = 0.18 | Точность = 0.279, Полнота = 0.936 | F1-мера = 0.430
# Порог = 0.20 | Точность = 0.279, Полнота = 0.936 | F1-мера = 0.430
# Порог = 0.22 | Точность = 0.279, Полнота = 0.936 | F1-мера = 0.430
# Порог = 0.24 | Точность = 0.279, Полнота = 0.936 | F1-мера = 0.430
# Порог = 0.26 | Точность = 0.279, Полнота = 0.936 | F1-мера = 0.430
# ...

# %% [markdown]
# Наилучшие метрики при пороге 0.74.

# %% [markdown]
# #### Случайный лес

# %% [markdown]
# Подберем оптимальные гиперпараметры для модели случайного леса, будем менять гиперпараметры следующим образом: - с количеством деревьев: от 10 до 100 с шагом 10 (n_estimators), - с максимальной глубиной от 1 до 15 (max_depth).
#
# Так как чем больше деревьев, тем дольше учится модель, поэтому сначала подберем глубину леса при небольшом числе деревьев.

# %%
model_rf_balanced = None # переменная для лучшей модели (случайный лес)
best_result_rf = 0 # переменная для f1 лучшей модели (случайный лес)
best_roc_auc = 0 # переменная для roc_auc лучшей модели (случайный лес)
best_est_rf_balanced = 0 # переменная для n_estimators лучшей модели (случайный лес)
best_depth_rf_balanced = 0 # переменная для max_depth лучшей модели (случайный лес)
# перебираем количество деревьев от 10 до 100 с шагом 10
for est in range(10, 101, 10):
    # перебираем глубину дерева от 1 до 15
    for depth in tqdm(range (1, 16)):
        # создадим модель с параметром задаваемым в цикле
        model = RandomForestClassifier(random_state=MY_RANDOM_STATE,n_estimators=est,max_depth=depth, 
                                       class_weight = 'balanced')
        model.fit(features_train,target_train) # обучение модели на тренировочной выборке
        predicted_valid = model.predict(features_valid) # предсказание на валидационной выборке
        result = f1_score(target_valid, predicted_valid) # высчитываем f1
        predictions = model.predict_proba(features_valid)# найдем вероятности классов
        roc_auc =  roc_auc_score(target_valid, predictions[:, 1]) # высчитываем ROC AUC
        # найдем лучшую модель
        if result > best_result_rf:
            model_rf_balanced = model # сохраняем наилучшую модель
            best_result_rf = result # сохраняем f1 для наилучшей модели
            best_roc_auc = roc_auc # сохраняем roc_auc для наилучшей модели
            best_est_rf_balanced = est # сохраняем значение количества деревьев для наилучшей модели
            best_depth_rf_balanced = depth # сохраняем значение глубины дерева для наилучшей модели

print("F1 наилучшей модели:", best_result_rf, "AUC-ROC:", best_roc_auc,
      "Количество деревьев:", best_est_rf_balanced, "Максимальная глубина:", best_depth_rf_balanced)
# Out:
# ...
# 100%|██████████| 15/15 [00:08<00:00,  1.76it/s]
# F1 наилучшей модели: 0.6058479532163743 AUC-ROC: 0.8448307715045817 Количество деревьев: 60 Максимальная глубина: 9

# %% [markdown]
# Теперь изменим порог и построим PR-кривую и ROC-кривую.

# %%
# вызовем функцию для подбора порога и построения PR-кривой и ROC-кривой
ml_threshold(model_rf_balanced, 
             [features_valid, target_valid], 
             f1_score_list_balanced, 
             auc_roc_score_list_balanced,
             threshold_list_balanced)
# Out:
# Статистика модели
# Порог = 0.00 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.02 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.04 | Точность = 0.207, Полнота = 0.998 | F1-мера = 0.343
# Порог = 0.06 | Точность = 0.216, Полнота = 0.998 | F1-мера = 0.355
# Порог = 0.08 | Точность = 0.227, Полнота = 0.995 | F1-мера = 0.370
# Порог = 0.10 | Точность = 0.239, Полнота = 0.988 | F1-мера = 0.385
# Порог = 0.12 | Точность = 0.247, Полнота = 0.983 | F1-мера = 0.394
# Порог = 0.14 | Точность = 0.256, Полнота = 0.973 | F1-мера = 0.405
# Порог = 0.16 | Точность = 0.267, Полнота = 0.968 | F1-мера = 0.418
# Порог = 0.18 | Точность = 0.275, Полнота = 0.944 | F1-мера = 0.426
# Порог = 0.20 | Точность = 0.289, Полнота = 0.931 | F1-мера = 0.441
# Порог = 0.22 | Точность = 0.306, Полнота = 0.924 | F1-мера = 0.460
# Порог = 0.24 | Точность = 0.329, Полнота = 0.914 | F1-мера = 0.483
# Порог = 0.26 | Точность = 0.342, Полнота = 0.887 | F1-мера = 0.493
# ...

# %% [markdown]
# Лучшие результаты модель показала при пороге 0.5.

# %% [markdown]
# **Вывод:** при применении гиперпараметра `class_weight = 'balanced'` для борьбы с дисбалансом классов лучшие результаты показали:
# - модель логистической регрессии с порогом 0.54: F1 = 0,49 и AUC-ROC = 0.74 - такие же метрики, что и у модели без данного гиперпараметра;
# - модель дерева решений с порогом 0.64: F1 = 0.57, AUC-ROC = 0.82, это практически такие же результаты, как без этого параметра;
# - модель случайного леса с порогом 0.5: F1 = 0,61 и AUC-ROC = 0.84. Результат по метрикам случайного леса лучше результата без применения гиперпараметра class_weight = 'balanced'.

# %% [markdown]
# Построим сводную таблицу с метриками построенных моделей при использовании параметра `class_weight = 'balanced'`.

# %%
# сформируем сводную таблицу 
score_table_balanced = pd.DataFrame(
    {'Модель': model_names, 
     'Взвешенные данные (F1)': f1_score_list_balanced,
     'Взвешенные данные (AUC-ROC)': auc_roc_score_list_balanced,
     'Оптимальный порог':threshold_list_balanced
    }
)               
score_table_balanced
# Out:
#                    Модель  Взвешенные данные (F1)  \
# 0      LogisticRegression                  0.4777
# 1  DecisionTreeClassifier                  0.5714
# 2  RandomForestClassifier                  0.6130
#
#    Взвешенные данные (AUC-ROC)  Оптимальный порог
# 0                       0.7426               0.52
# 1                       0.8275               0.46
# 2                       0.8448               0.52

# %% [markdown]
# ### Увеличение выборки

# %% [markdown]
# Теперь воспользуемся техникой upsampling, чтобы увеличить количество редкого класса. Напишем функцию, которая на вход будет принимать признаки, целевые значения и количество раз, в которое необходимо увеличить меньший класс, чтобы выборка стала сбалансированной. В результате работы функции получим увеличенную исходную выборку со сбалансированными классами.

# %%
# функция для увеличения редкого класса
def upsample(features, target, repeat):
    features_zeros = features[target == 0] # выделим признаки отрицательного класса
    features_ones = features[target == 1] # выделим признаки положительного класса
    target_zeros = target[target == 0] # выделим целевой признак отрицательного класса
    target_ones = target[target == 1] # выделим целевой признак положительного класса
    # увеличим положительный класс и объединим с отрицательным
    features_upsampled = pd.concat([features_zeros] + [features_ones] * repeat) 
    target_upsampled = pd.concat([target_zeros] + [target_ones] * repeat)    
    features_upsampled, target_upsampled = shuffle(
        features_upsampled, target_upsampled, random_state=MY_RANDOM_STATE) # перемешаем данные  
    return features_upsampled, target_upsampled

# %% [markdown]
# Получим тренировочную выборку со сбалансированными классами. Так как положительный класс в 4 раза меньше отрицательного, то увеличим количество положительных объектов в 4 раза.

# %%
# признаки и целевое значение увеличенной обучающей выборки 
features_train_upsampled, target_train_upsampled = upsample(features_train, target_train, 4)

# %% [markdown]
# Проверим размерность получившихся выборок.

# %%
print(features_train_upsampled.shape)
print(target_train_upsampled.shape)
# Out:
# (9666, 11)
# (9666,)

# %%
print(features_train.shape)
print(target_train.shape)
# Out:
# (6000, 11)
# (6000,)

# %% [markdown]
# Увеличение выборки прошло корректно.

# %% [markdown]
# #### Логистическая регрессия

# %%
# рассчитаем модель логистической регрессии на увеличенной выборке
model_lr_upsampled = LogisticRegression(random_state=MY_RANDOM_STATE, solver='liblinear')
model_lr_upsampled.fit(features_train_upsampled, target_train_upsampled)
predicted_valid = model_lr_upsampled.predict(features_valid)
predictions = model_lr_upsampled.predict_proba(features_valid)# найдем вероятности классов

print("F1 модели на валидационной выборке:", f1_score(target_valid, predicted_valid))
print("AUC-ROC модели на валидационной выборке:", roc_auc_score(target_valid, predictions[:, 1]))
# Out:
# F1 модели на валидационной выборке: 0.4684838160136287
# AUC-ROC модели на валидационной выборке: 0.7426578357473643

# %% [markdown]
# Найдем оптимальный порог классификации для логистической регрессии. Переберем значения порогов от 0 до 0.9 с шагом 0.02 и найдем для каждого значения метрики: точность, полноту, F1-меру и AUC-ROC. Построим PR-кривую и ROC-кривую.

# %%
# создадим список для сохранения F1-метрики и AUC_ROC
f1_score_list_upsampled = []
auc_roc_score_list_upsampled = []
threshold_list_upsampled = []

# %%
# вызовем функцию для подбора порога и построения PR-кривой и ROC-кривой
ml_threshold(model_lr_upsampled, 
             [features_valid, target_valid], 
             f1_score_list_upsampled, 
             auc_roc_score_list_upsampled,
             threshold_list_upsampled)
# Out:
# Статистика модели
# Порог = 0.00 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.02 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.04 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.06 | Точность = 0.204, Полнота = 0.998 | F1-мера = 0.339
# Порог = 0.08 | Точность = 0.206, Полнота = 0.998 | F1-мера = 0.342
# Порог = 0.10 | Точность = 0.209, Полнота = 0.995 | F1-мера = 0.346
# Порог = 0.12 | Точность = 0.212, Полнота = 0.993 | F1-мера = 0.350
# Порог = 0.14 | Точность = 0.218, Полнота = 0.988 | F1-мера = 0.357
# Порог = 0.16 | Точность = 0.223, Полнота = 0.983 | F1-мера = 0.364
# Порог = 0.18 | Точность = 0.228, Полнота = 0.971 | F1-мера = 0.369
# Порог = 0.20 | Точность = 0.234, Полнота = 0.958 | F1-мера = 0.376
# Порог = 0.22 | Точность = 0.240, Полнота = 0.949 | F1-мера = 0.384
# Порог = 0.24 | Точность = 0.247, Полнота = 0.939 | F1-мера = 0.391
# Порог = 0.26 | Точность = 0.252, Полнота = 0.917 | F1-мера = 0.396
# ...

# %% [markdown]
# Наилучшие метрики достигаются при пороге = 0.54.

# %% [markdown]
# #### Дерево решений

# %% [markdown]
# Обучим модели дерево решений, при этом меняя гиперпараметр - max_depth - глубина дерева. Переберем значения от 1 до 15.

# %%
model_dt_upsampled = None # переменная для лучшей модели (дерево решение)
best_f1_dt = 0 # переменная для f1 лучшей модели (дерево решение)
best_roc_auc_dt = 0 # переменная для ROC AUC лучшей модели (дерево решение)
best_depth_dt_upsampled = 0 # переменная для max_depth лучшей модели (дерево решение)
# перебираем глубину дерева от 1 до 15
for depth in range(1, 16):
    # создадим модель с параметром, задаваемым в цикле
    model = DecisionTreeClassifier(max_depth=depth, random_state=MY_RANDOM_STATE)
    model.fit(features_train_upsampled,target_train_upsampled) # обучение модели на тренировочной выборке
    predicted_valid = model.predict(features_valid) # предсказание на валидационной выборке
    f1 = f1_score(target_valid, predicted_valid) # высчитываем accuracy
    predictions = model.predict_proba(features_valid)# найдем вероятности классов
    roc_auc =  roc_auc_score(target_valid, predictions[:, 1]) # высчитываем ROC AUC
    # запишем параметры в список
    max_depth_list_dt.append(depth)
    f1_list_dt.append(f1)
    roc_auc_list_dt.append(roc_auc)
    # найдем лучшую модель
    if f1 > best_f1_dt:
        model_dt_upsampled = model # сохраняем наилучшую модель
        best_f1_dt = f1 # сохраняем f1 для наилучшей модели
        best_roc_auc_dt = roc_auc # сохраняем f1 для наилучшей модели
        best_depth_dt_upsampled = depth # сохраняем значение глубины дерева для наилучшей модели

print("F1 наилучшей модели на валидационной выборке:", best_f1_dt, "AUC-ROC:", best_roc_auc_dt, "Глубина дерева:", best_depth_dt_upsampled)
# Out:
# F1 наилучшей модели на валидационной выборке: 0.5719626168224299 AUC-ROC: 0.827830943935363 Глубина дерева: 5

# %% [markdown]
# Изменим порог и построим PR-кривую и ROC-кривую.

# %%
# вызовем функцию для подбора порога и построения PR-кривой и ROC-кривой
ml_threshold(model_dt_upsampled, 
             [features_valid, target_valid], 
             f1_score_list_upsampled, 
             auc_roc_score_list_upsampled,
             threshold_list_upsampled)
# Out:
# Статистика модели
# Порог = 0.00 | Точность = 0.205, Полнота = 1.000 | F1-мера = 0.340
# Порог = 0.02 | Точность = 0.205, Полнота = 1.000 | F1-мера = 0.340
# Порог = 0.04 | Точность = 0.230, Полнота = 0.998 | F1-мера = 0.374
# Порог = 0.06 | Точность = 0.234, Полнота = 0.995 | F1-мера = 0.378
# Порог = 0.08 | Точность = 0.234, Полнота = 0.995 | F1-мера = 0.378
# Порог = 0.10 | Точность = 0.234, Полнота = 0.995 | F1-мера = 0.378
# Порог = 0.12 | Точность = 0.254, Полнота = 0.971 | F1-мера = 0.403
# Порог = 0.14 | Точность = 0.254, Полнота = 0.971 | F1-мера = 0.403
# Порог = 0.16 | Точность = 0.280, Полнота = 0.936 | F1-мера = 0.431
# Порог = 0.18 | Точность = 0.280, Полнота = 0.936 | F1-мера = 0.431
# Порог = 0.20 | Точность = 0.280, Полнота = 0.936 | F1-мера = 0.431
# Порог = 0.22 | Точность = 0.280, Полнота = 0.936 | F1-мера = 0.431
# Порог = 0.24 | Точность = 0.280, Полнота = 0.936 | F1-мера = 0.431
# Порог = 0.26 | Точность = 0.280, Полнота = 0.936 | F1-мера = 0.431
# ...

# %% [markdown]
# После изменения порога метрики изменились несильно. Наилучшие метрики достигаются при пороге 0.54.

# %% [markdown]
# #### Случайный лес

# %% [markdown]
# Подберем оптимальные гиперпараметры для модели случайного леса, будем менять гиперпараметры следующим образом:
# - с количеством деревьев: от 10 до 100 с шагом 10 (n_estimators),
# - с максимальной глубиной от 1 до 15 (max_depth).
#
# Так как чем больше деревьев, тем дольше учится модель, поэтому сначала подберем глубину леса при небольшом числе деревьев.

# %%
model_rf_upsampled = None # переменная для лучшей модели (случайный лес)
best_result_rf = 0 # переменная для f1 лучшей модели (случайный лес)
best_roc_auc = 0 # переменная для roc_auc лучшей модели (случайный лес)
best_est_rf_upsampled = 0 # переменная для n_estimators лучшей модели (случайный лес)
best_depth_rf_upsampled = 0 # переменная для max_depth лучшей модели (случайный лес)
# перебираем количество деревьев от 10 до 100 с шагом 10
for est in range(10, 101, 10):
    # перебираем глубину дерева от 1 до 15
    for depth in tqdm(range (1, 16)):
        # создадим модель с параметром задаваемым в цикле
        model = RandomForestClassifier(random_state=MY_RANDOM_STATE,n_estimators=est,max_depth=depth)
        model.fit(features_train_upsampled,target_train_upsampled) # обучение модели на тренировочной выборке
        predicted_valid = model.predict(features_valid) # предсказание на валидационной выборке
        result = f1_score(target_valid, predicted_valid) # высчитываем f1
        predictions = model.predict_proba(features_valid)# найдем вероятности классов
        roc_auc =  roc_auc_score(target_valid, predictions[:, 1]) # высчитываем ROC AUC
        # найдем лучшую модель
        if result > best_result_rf:
            model_rf_upsampled = model # сохраняем наилучшую модель
            best_result_rf = result # сохраняем f1 для наилучшей модели
            best_roc_auc = roc_auc # сохраняем roc_auc для наилучшей модели
            best_est_rf_upsampled = est # сохраняем значение количества деревьев для наилучшей модели
            best_depth_rf_upsampled = depth # сохраняем значение глубины дерева для наилучшей модели

print("F1 наилучшей модели:", best_result_rf, "AUC-ROC:", best_roc_auc,
      "Количество деревьев:", best_est_rf_upsampled, "Максимальная глубина:", best_depth_rf_upsampled)
# Out:
# ...
# 100%|██████████| 15/15 [00:11<00:00,  1.34it/s]
# F1 наилучшей модели: 0.6047087980173482 AUC-ROC: 0.8375979160508424 Количество деревьев: 50 Максимальная глубина: 14

# %% [markdown]
# Теперь изменим порог и построим PR-кривую и ROC-кривую.

# %%
# вызовем функцию для подбора порога и построения PR-кривой и ROC-кривой
ml_threshold(model_rf_upsampled, 
             [features_valid, target_valid], 
             f1_score_list_upsampled, 
             auc_roc_score_list_upsampled,
             threshold_list_upsampled)
# Out:
# Статистика модели
# Порог = 0.00 | Точность = 0.205, Полнота = 0.998 | F1-мера = 0.340
# Порог = 0.02 | Точность = 0.225, Полнота = 0.993 | F1-мера = 0.367
# Порог = 0.04 | Точность = 0.241, Полнота = 0.983 | F1-мера = 0.387
# Порог = 0.06 | Точность = 0.254, Полнота = 0.968 | F1-мера = 0.402
# Порог = 0.08 | Точность = 0.267, Полнота = 0.956 | F1-мера = 0.418
# Порог = 0.10 | Точность = 0.281, Полнота = 0.951 | F1-мера = 0.433
# Порог = 0.12 | Точность = 0.294, Полнота = 0.936 | F1-мера = 0.447
# Порог = 0.14 | Точность = 0.308, Полнота = 0.922 | F1-мера = 0.462
# Порог = 0.16 | Точность = 0.328, Полнота = 0.912 | F1-мера = 0.482
# Порог = 0.18 | Точность = 0.340, Полнота = 0.900 | F1-мера = 0.494
# Порог = 0.20 | Точность = 0.354, Полнота = 0.877 | F1-мера = 0.505
# Порог = 0.22 | Точность = 0.365, Полнота = 0.846 | F1-мера = 0.510
# Порог = 0.24 | Точность = 0.381, Полнота = 0.816 | F1-мера = 0.519
# Порог = 0.26 | Точность = 0.390, Полнота = 0.789 | F1-мера = 0.522
# ...

# %% [markdown]
# С помощью изменения порога мы смогли немного улучшить нашу модель: F1 = 0.64, AUC-ROC = 0.79.
# Лучшее значение порога: 0.48

# %% [markdown]
# **Вывод:**
# 1. Техникой upsampling было увеличено в 4 раза количество объектов положительного класса.
# 2. При применении техники upsampling для борьбы с дисбалансом классов лучшие метрики показали:
# - модель логистической регрессии с порогом = 0.54: F1 = 0.49, AUC-ROC = 0.74. То есть результат такой же, как на несбалансированных данных;
# - модель дерева решений с порогом 0.64: F1 = 0.57, AUC-ROC = 0.82. Таким образом, метрики практически не улучшились по сравнению с моделью на несбалансированных данных;
# - модель случайного леса с порогом 0.5: F1 = 0.61, AUC-ROC = 0.84. То есть результат улучшился по сравнению с моделью на несбалансированных данных.

# %% [markdown]
# Выведим сводную таблицу с метриками построенных моделей при использовании техники upsampling для борьбы с дисбалансом.

# %%
# сформируем сводную таблицу 
score_table_upsampled = pd.DataFrame(
    {'Модель': model_names, 
     'Upsampled (F1)': f1_score_list_upsampled,
     'Upsampled (AUC-ROC)': auc_roc_score_list_upsampled,
     'Оптимальный порог':threshold_list_upsampled
    }
)               
score_table_upsampled
# Out:
#                    Модель  Upsampled (F1)  Upsampled (AUC-ROC)  \
# 0      LogisticRegression          0.4798               0.7427
# 1  DecisionTreeClassifier          0.5720               0.8278
# 2  RandomForestClassifier          0.6063               0.8376
#
#    Оптимальный порог
# 0               0.54
# 1               0.46
# 2               0.48

# %% [markdown]
# ### Уменьшение выборки

# %% [markdown]
# Воспользуемся техникой downsampling - отбросим часть из отрицательных объектов. Для этого напишем функцию, которая на вход будет принимать признаки, целевые значения и долю объектов отрицательного класса, которые необходимо оставить. В результате работы функции получим уменьшенную исходную выборку со сбалансированными классами.

# %%
# функция, которая сбалансирует выборку техникой downsampling
def downsample(features, target, fraction):
    features_zeros = features[target == 0] # выделим признаки отрицательного класса
    features_ones = features[target == 1] # выделим признаки положительного класса
    target_zeros = target[target == 0] # выделим целевой признак отрицательного класса
    target_ones = target[target == 1] # выделим целевой признак положительного класса
    # уменьшим отрицательный класс и объединим с положительным
    features_downsampled = pd.concat(
        [features_zeros.sample(frac=fraction, random_state=MY_RANDOM_STATE)] + [features_ones])
    target_downsampled = pd.concat(
        [target_zeros.sample(frac=fraction, random_state=MY_RANDOM_STATE)] + [target_ones])    
    features_downsampled, target_downsampled = shuffle(
        features_downsampled, target_downsampled, random_state=MY_RANDOM_STATE) # перемешаем данные 
    return features_downsampled, target_downsampled

# %% [markdown]
# Получим тренировочную выборку со сбалансированными классами. Так как положительный класс в 4 раза меньше отрицательного, то оставим 0.25 всех объектов отрицательного класса.

# %%
# признаки и целевое значение увеличенной обучающей выборки 
features_train_downsampled, target_train_downsampled = downsample(features_train, target_train, 0.25)

# %% [markdown]
# Проверим размерность получившихся выборок.

# %%
print(features_train_downsampled.shape)
print(target_train_downsampled.shape)
# Out:
# (2416, 11)
# (2416,)

# %%
print(features_train.shape)
print(target_train.shape)
# Out:
# (6000, 11)
# (6000,)

# %% [markdown]
# Уменьшение выборки прошло корректно.

# %% [markdown]
# #### Логистическая регрессия

# %%
# рассчитаем модель логистической регрессии на увеличенной выборке
model_lr_downsampled = LogisticRegression(random_state=MY_RANDOM_STATE, solver='liblinear')
model_lr_downsampled.fit(features_train_downsampled, target_train_downsampled)
predicted_valid = model_lr_downsampled.predict(features_valid)
predictions = model_lr_downsampled.predict_proba(features_valid)# найдем вероятности классов
print("F1:", f1_score(target_valid, predicted_valid))
print("ROC_auc:", roc_auc_score(target_valid, predictions[:, 1]))
# Out:
# F1: 0.475609756097561
# ROC_auc: 0.7431335599566459

# %% [markdown]
# Найдем оптимальный порог классификации для логистической регрессии. Переберем значения порогов от 0 до 0.9 с шагом 0.02 и найдем для каждого значения метрики: точность, полноту, F1-меру и AUC-ROC. Построим PR-кривую и ROC-кривую.

# %%
# создадим список для сохранения F1-метрики и AUC_ROC
f1_score_list_downsampled = []
auc_roc_score_list_downsampled = []
threshold_list_downsampled = []

# %%
# вызовем функцию для подбора порога и построения PR-кривой и ROC-кривой
ml_threshold(model_lr_downsampled, 
             [features_valid, target_valid], 
             f1_score_list_downsampled, 
             auc_roc_score_list_downsampled,
             threshold_list_downsampled)
# Out:
# Статистика модели
# Порог = 0.00 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.02 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.04 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.06 | Точность = 0.204, Полнота = 0.998 | F1-мера = 0.339
# Порог = 0.08 | Точность = 0.205, Полнота = 0.998 | F1-мера = 0.340
# Порог = 0.10 | Точность = 0.208, Полнота = 0.995 | F1-мера = 0.344
# Порог = 0.12 | Точность = 0.211, Полнота = 0.995 | F1-мера = 0.349
# Порог = 0.14 | Точность = 0.216, Полнота = 0.993 | F1-мера = 0.355
# Порог = 0.16 | Точность = 0.221, Полнота = 0.983 | F1-мера = 0.361
# Порог = 0.18 | Точность = 0.226, Полнота = 0.973 | F1-мера = 0.367
# Порог = 0.20 | Точность = 0.232, Полнота = 0.958 | F1-мера = 0.373
# Порог = 0.22 | Точность = 0.238, Полнота = 0.953 | F1-мера = 0.380
# Порог = 0.24 | Точность = 0.244, Полнота = 0.939 | F1-мера = 0.388
# Порог = 0.26 | Точность = 0.251, Полнота = 0.919 | F1-мера = 0.394
# ...

# %% [markdown]
# Наилучшие метрики F1 = 0.53, AUC-ROC = 0.73 при пороге = 0.54.

# %% [markdown]
# #### Дерево решений

# %% [markdown]
# Обучим модели дерево решений, при этом меняя гиперпараметр - max_depth - глубина дерева. Переберем значения от 1 до 15.

# %%
model_dt_downsampled = None # переменная для лучшей модели (дерево решение)
best_f1_dt = 0 # переменная для f1 лучшей модели (дерево решение)
best_roc_auc_dt = 0 # переменная для ROC AUC лучшей модели (дерево решение)
best_depth_dt_downsampled = 0 # переменная для max_depth лучшей модели (дерево решение)
# перебираем глубину дерева от 1 до 15
for depth in range(1, 16):
    # создадим модель с параметром, задаваемым в цикле
    model = DecisionTreeClassifier(max_depth=depth, random_state=MY_RANDOM_STATE)
    model.fit(features_train_downsampled,target_train_downsampled) # обучение модели на тренировочной выборке
    predicted_valid = model.predict(features_valid) # предсказание на валидационной выборке
    f1 = f1_score(target_valid, predicted_valid) # высчитываем accuracy
    predictions = model.predict_proba(features_valid)# найдем вероятности классов
    roc_auc =  roc_auc_score(target_valid, predictions[:, 1]) # высчитываем ROC AUC
    # запишем параметры в список
    max_depth_list_dt.append(depth)
    f1_list_dt.append(f1)
    roc_auc_list_dt.append(roc_auc)
    # найдем лучшую модель
    if f1 > best_f1_dt:
        model_dt_downsampled = model # сохраняем наилучшую модель
        best_f1_dt = f1 # сохраняем f1 для наилучшей модели
        best_roc_auc_dt = roc_auc # сохраняем f1 для наилучшей модели
        best_depth_dt_downsampled = depth # сохраняем значение глубины дерева для наилучшей модели

print("F1 наилучшей модели на валидационной выборке:", best_f1_dt, "AUC-ROC:", best_roc_auc_dt, "Глубина дерева:", best_depth_dt_downsampled)
# Out:
# F1 наилучшей модели на валидационной выборке: 0.5604498594189314 AUC-ROC: 0.8251128497881565 Глубина дерева: 6

# %% [markdown]
# Изменим порог и построим PR-кривую и ROC-кривую.

# %%
# вызовем функцию для подбора порога и построения PR-кривой и ROC-кривой
ml_threshold(model_dt_downsampled, 
             [features_valid, target_valid], 
             f1_score_list_downsampled, 
             auc_roc_score_list_downsampled,
             threshold_list_downsampled)
# Out:
# Статистика модели
# Порог = 0.00 | Точность = 0.205, Полнота = 0.998 | F1-мера = 0.340
# Порог = 0.02 | Точность = 0.230, Полнота = 0.995 | F1-мера = 0.373
# Порог = 0.04 | Точность = 0.230, Полнота = 0.995 | F1-мера = 0.373
# Порог = 0.06 | Точность = 0.230, Полнота = 0.995 | F1-мера = 0.373
# Порог = 0.08 | Точность = 0.246, Полнота = 0.968 | F1-мера = 0.392
# Порог = 0.10 | Точность = 0.259, Полнота = 0.949 | F1-мера = 0.407
# Порог = 0.12 | Точность = 0.259, Полнота = 0.949 | F1-мера = 0.407
# Порог = 0.14 | Точность = 0.264, Полнота = 0.946 | F1-мера = 0.413
# Порог = 0.16 | Точность = 0.264, Полнота = 0.946 | F1-мера = 0.413
# Порог = 0.18 | Точность = 0.264, Полнота = 0.946 | F1-мера = 0.413
# Порог = 0.20 | Точность = 0.271, Полнота = 0.934 | F1-мера = 0.420
# Порог = 0.22 | Точность = 0.310, Полнота = 0.885 | F1-мера = 0.459
# Порог = 0.24 | Точность = 0.310, Полнота = 0.885 | F1-мера = 0.459
# Порог = 0.26 | Точность = 0.353, Полнота = 0.833 | F1-мера = 0.496
# ...

# %% [markdown]
# Наилучшие метрики: F1 = 0.62 AUC-ROC = 0.78 при пороге 0.64.

# %% [markdown]
# #### Случайный лес

# %% [markdown]
# Подберем оптимальные гиперпараметры для модели случайного леса, будем менять гиперпараметры следующим образом:
# - с количеством деревьев: от 10 до 100 с шагом 10 (n_estimators),
# - с максимальной глубиной от 1 до 15 (max_depth).
#
# Так как чем больше деревьев, тем дольше учится модель, поэтому сначала подберем глубину леса при небольшом числе деревьев.

# %%
model_rf_downsampled = None # переменная для лучшей модели (случайный лес)
best_result_rf = 0 # переменная для f1 лучшей модели (случайный лес)
best_roc_auc = 0 # переменная для roc_auc лучшей модели (случайный лес)
best_est_rf_downsampled = 0 # переменная для n_estimators лучшей модели (случайный лес)
best_depth_rf_downsampled = 0 # переменная для max_depth лучшей модели (случайный лес)
# перебираем количество деревьев от 10 до 100 с шагом 10
for est in range(10, 101, 10):
    # перебираем глубину дерева от 1 до 15
    for depth in tqdm(range (1, 16)):
        # создадим модель с параметром задаваемым в цикле
        model = RandomForestClassifier(random_state=MY_RANDOM_STATE,n_estimators=est,max_depth=depth)
        model.fit(features_train_downsampled,target_train_downsampled) # обучение модели на тренировочной выборке
        predicted_valid = model.predict(features_valid) # предсказание на валидационной выборке
        result = f1_score(target_valid, predicted_valid) # высчитываем f1
        predictions = model.predict_proba(features_valid)# найдем вероятности классов
        roc_auc =  roc_auc_score(target_valid, predictions[:, 1]) # высчитываем ROC AUC
        # найдем лучшую модель
        if result > best_result_rf:
            model_rf_downsampled = model # сохраняем наилучшую модель
            best_result_rf = result # сохраняем f1 для наилучшей модели
            best_roc_auc = roc_auc # сохраняем roc_auc для наилучшей модели
            best_est_rf_downsampled = est # сохраняем значение количества деревьев для наилучшей модели
            best_depth_rf_downsampled = depth # сохраняем значение глубины дерева для наилучшей модели

print("F1 наилучшей модели:", best_result_rf, "AUC-ROC:", best_roc_auc,
      "Количество деревьев:", best_est_rf_downsampled, "Максимальная глубина:", best_depth_rf_downsampled)
# Out:
# ...
# 100%|██████████| 15/15 [00:05<00:00,  2.89it/s]
# F1 наилучшей модели: 0.5833333333333334 AUC-ROC: 0.8359013203271258 Количество деревьев: 20 Максимальная глубина: 6

# %% [markdown]
# Теперь изменим порог и построим PR-кривую и ROC-кривую.

# %%
# вызовем функцию для подбора порога и построения PR-кривой и ROC-кривой
ml_threshold(model_rf_downsampled, 
             [features_valid, target_valid], 
             f1_score_list_downsampled, 
             auc_roc_score_list_downsampled,
             threshold_list_downsampled)
# Out:
# Статистика модели
# Порог = 0.00 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.02 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.04 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.06 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.08 | Точность = 0.204, Полнота = 1.000 | F1-мера = 0.339
# Порог = 0.10 | Точность = 0.209, Полнота = 0.998 | F1-мера = 0.346
# Порог = 0.12 | Точность = 0.220, Полнота = 0.998 | F1-мера = 0.361
# Порог = 0.14 | Точность = 0.224, Полнота = 0.998 | F1-мера = 0.366
# Порог = 0.16 | Точность = 0.229, Полнота = 0.993 | F1-мера = 0.372
# Порог = 0.18 | Точность = 0.238, Полнота = 0.990 | F1-мера = 0.384
# Порог = 0.20 | Точность = 0.245, Полнота = 0.978 | F1-мера = 0.392
# Порог = 0.22 | Точность = 0.252, Полнота = 0.971 | F1-мера = 0.400
# Порог = 0.24 | Точность = 0.259, Полнота = 0.963 | F1-мера = 0.409
# Порог = 0.26 | Точность = 0.266, Полнота = 0.956 | F1-мера = 0.416
# ...

# %% [markdown]
# Изменение порога не дало ощутимых результатов: F1 = 0.6352, AUC-ROC=0.7691. Лучшее значение порога: 0.62.

# %% [markdown]
# **Вывод:**
# 1. Техникой downsampling было оставлено 0.25 часть количества объектов отрицательного класса.
# 2. При применении техники downsampling для борьбы с дисбалансом классов лучшие метрики показали:
# - модель логистической регрессии с порогом = 0.54: F1 = 0.49, AUC-ROC = 0.74. То есть результат чуть хуже, чем на несбалансированных данных;
# - модель дерева решений: F1 = 0.56, AUC-ROC = 0.81. Таким образом, метрики ухудшились по сравнению с моделью на несбалансированных данных;
# - модель случайного леса с порогом 0.6: F1 = 0.58, AUC-ROC = 0.83. Что так же хуже по сравнению с моделью на несбалансированных данных.

# %% [markdown]
# Выведим сводную таблицу с метриками построенных моделей при использовании техники downsampling для борьбы с дисбалансом.

# %%
# сформируем сводную таблицу 
score_table_downsampled = pd.DataFrame(
    {'Модель': model_names, 
     'Downsampled (F1)': f1_score_list_downsampled,
     'Downsampled (AUC-ROC)': auc_roc_score_list_downsampled,
     'Оптимальный порог':threshold_list_downsampled
    }
)               
score_table_downsampled
# Out:
#                    Модель  Downsampled (F1)  Downsampled (AUC-ROC)  \
# 0      LogisticRegression            0.4785                 0.7431
# 1  DecisionTreeClassifier            0.5925                 0.8251
# 2  RandomForestClassifier            0.5911                 0.8359
#
#    Оптимальный порог
# 0               0.52
# 1               0.60
# 2               0.52

# %% [markdown]
# ## Тестирование модели

# %% [markdown]
# В предыдущем разделе были обучены несколько моделей, теперь наилучшую модель проверим на тестовой выборке.
#
# Посмотрим на F1-меру и AUC-ROC для всех моделей.

# %%
# сформируем сводную таблицу по F1-мере для всех моделей
# составим список обученных моделей
model_names = ['LogisticRegression', 'DecisionTreeClassifier', 'RandomForestClassifier']
score_table_f1 = pd.DataFrame(
    {'Модель': model_names, 
     'Несбалансированные данные (F1)': f1_score_list, 
     'Взвешенные данные (F1)': f1_score_list_balanced,
     'Upsampled данные (F1)': f1_score_list_upsampled,
     'Downsampled данные (F1)': f1_score_list_downsampled
    }
)               
score_table_f1
# Out:
#                    Модель  Несбалансированные данные (F1)  \
# 0      LogisticRegression                          0.4718
# 1  DecisionTreeClassifier                          0.5773
# 2  RandomForestClassifier                          0.5879
#
#    Взвешенные данные (F1)  Upsampled данные (F1)  Downsampled данные (F1)
# 0                  0.4777                 0.4798                   0.4785
# 1                  0.5714                 0.5720                   0.5925
# 2                  0.6130                 0.6063                   0.5911

# %%
# сформируем сводную таблицу по AUC-ROC для всех моделей
# составим список обученных моделей
model_names = ['LogisticRegression', 'DecisionTreeClassifier', 'RandomForestClassifier']
score_table_auc_roc = pd.DataFrame(
    {'Модель': model_names, 
     'Несбалансированные данные (AUC-ROC)': auc_roc_score_list, 
     'Взвешенные данные (AUC-ROC)': auc_roc_score_list_balanced,
     'Upsampled данные (AUC-ROC)': auc_roc_score_list_upsampled,
     'Downsampled данные (AUC-ROC)': auc_roc_score_list_downsampled
    }
)               
score_table_auc_roc
# Out:
#                    Модель  Несбалансированные данные (AUC-ROC)  \
# 0      LogisticRegression                               0.7402
# 1  DecisionTreeClassifier                               0.8197
# 2  RandomForestClassifier                               0.8352
#
#    Взвешенные данные (AUC-ROC)  Upsampled данные (AUC-ROC)  \
# 0                       0.7426                      0.7427
# 1                       0.8275                      0.8278
# 2                       0.8448                      0.8376
#
#    Downsampled данные (AUC-ROC)
# 0                        0.7431
# 1                        0.8251
# 2                        0.8359

# %% [markdown]
# Как мы видим, с совсем небольшим отрывом самые лучшие результаты показала модель случайного леса при использовании параметра class_weight = 'balanced': F1=0.61, AUC-ROC=0.84. Это модель `model_rf_balanced` (RandomForestClassifier(class_weight='balanced', max_depth=11, n_estimators=70)) при пороге 0.5 (`threshold_list_balanced[2]`).
#
# Посчитаем метрики на тестовых данных.

# %%
predicted_test = model_rf_balanced.predict(features_test) # предсказание на тестовой выборке
predictions = model.predict_proba(features_valid)# найдем вероятности классов
print('F1:', f1_score(target_test, predicted_test), '| ROC_AUC:', roc_auc_score(target_valid, predictions[:, 1]))
# Out:
# F1: 0.6643026004728133 | ROC_AUC: 0.8325951140506455

# %% [markdown]
# Наилучшие метрики достигаются при пороге 0.5 (`threshold_list_balanced[2]`), поэтому порог менять не имеет смысла.

# %% [markdown]
# Построим PR-кривую и ROC-кривую.

# %%
probabilities_test = model_rf_balanced.predict_proba(features_test)  # вычислим вероятность классов
# построим PR-кривую
precision, recall, thresholds = precision_recall_curve(target_test, probabilities_test[:, 1])    
plt.figure(figsize=(10, 10))
plt.step(recall, precision, where='post')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('PR-кривая')
     
# построим ROC-кривую
fpr, tpr, thresholds = roc_curve(target_test, probabilities_test[:, 1])
plt.figure(figsize=(10, 10))
plt.plot(fpr, tpr, linestyle='-')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
   
plt.show()

# %% [markdown]
# Попробуем еще улучшить нашу модель: обучим ее на тренировочной и валидационной выборке.

# %%
# обучим модель на объединенной выборке - train и valid
# для этого объединим выборки
features_train_valid = pd.concat((features_train, features_valid), axis=0)
target_train_valid = pd.concat((target_train, target_valid), axis=0)
features_train_valid.shape, target_train_valid.shape
# Out:
# ((8000, 11), (8000,))

# %% [markdown]
# Судя по размерности получившейся объединенной выборки - объединение прошло корректно.
#
# Теперь обучим наилучшую модель на получившейся выборке.

# %%
# создадим модель с лучшими параметрами
model_best_train_valid = RandomForestClassifier(random_state=MY_RANDOM_STATE,
                                                max_depth = best_depth_rf_balanced, 
                                                n_estimators = best_est_rf_balanced, 
                                                class_weight = 'balanced')
# обучим модель
model_best_train_valid.fit(features_train_valid, target_train_valid)
# Out:
# RandomForestClassifier(class_weight='balanced', max_depth=9, n_estimators=60)

# %% [markdown]
# Проверим обученную модель на тестовой выборке.

# %%
# прогнозирование модели 
predicted_test = model_best_train_valid.predict(features_test)
# посчитаем метрики
f1_score_best = f1_score(target_test, predicted_test)
predictions = model_best_train_valid.predict_proba(features_test)# найдем вероятности классов
roc_auc_score_best = roc_auc_score(target_test, predictions[:, 1])
print("F1 наилучшей модели:", f1_score_best, "AUC-ROC:", roc_auc_score_best,
      "Количество деревьев:", best_est_rf_balanced, "Максимальная глубина:", best_depth_rf_balanced)
# Out:
# F1 наилучшей модели: 0.6576271186440678 AUC-ROC: 0.8737150093082297 Количество деревьев: 60 Максимальная глубина: 9

# %% [markdown]
# Построим PR-кривую и ROC-кривую.

# %%
probabilities_test = model_best_train_valid.predict_proba(features_test)  # вычислим вероятность классов
# построим PR-кривую
precision, recall, thresholds = precision_recall_curve(target_test, probabilities_test[:, 1])    
plt.figure(figsize=(10, 10))
plt.step(recall, precision, where='post')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('PR-кривая')
     
# построим ROC-кривую
fpr, tpr, thresholds = roc_curve(target_test, probabilities_test[:, 1])
plt.figure(figsize=(10, 10))
plt.plot(fpr, tpr, linestyle='-')
plt.plot([0, 1], [0, 1], linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.0])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('ROC-кривая')
   
plt.show()

# %% [markdown]
# После обучения на объединенной выборке (обучающая + валидационная) метрики модели улучшились. Мы добились наилучшей F1-меры - 0.65 при AUC-ROC= 0.86.

# %% [markdown]
# **Вывод:**
# 1. Наилучшая модель RandomForestClassifier с параметром class_weight='balanced', максимальной глубиной - 11, количеством деревьев - 70 была проверена на тестовых данных: F1=0.61, ROC_AUC=0.84.
# 2. Так как на валидационной выборке было выяснено, что оптимальный порог для модель - 0.5, улучшать модель меняя преднастроенный порог, нет смысла.
# 3. Обучили модель на объединенной выборке (обучающая + валидационная) и посчитали метрики на тестовой выборке: F1=0.653, AUC-ROC=0.86. То есть результаты удалось еще улучшить.

# %% [markdown]
# ## Общий вывод

# %% [markdown]
# 1. Мы провели обзор и предобработку данных: был выявлен дисбаланс классов (объектов положительного класса всего 20% от всей выборки), сильный разброс значений признаков (требуется масштабирование), были обнаружены пропуски в столбце `Tenure`, которые вероятнее всего появились из-за какого-то сбоя в системе. Пропуски были заполнены медианным значением.
# 2. Целевым признаком определили данные об уходе клиента из банка - `exited`. Разбили данные на 3 выборки в соотношении 3:1:1 - обучающую, валидационную и тестовую. Данные были разбиты с учетом стратификации - случайного выбора объектов.
# 3. Были подготовлены признаки к обучению моделей:
# - категориальные признаки были преобразованы в численные с помощью техники прямого кодирования (One-Hot Encoding, OHE) с параметром  `drop='first'`, помогающим избежать "ловушки фиктивных признаков";
# - для числовых признаков была проведена стандартизация данных с помощью StandardScaler.
# 3. Задача была определена, как бинарная классификация. Для решения задачи были применены и исследованы три варианта моделирования: дерево решений, случайный лес и логистическая регрессия:
# - для моделей `Decision Tree` были проанализированы 15 вариантов: с гиперпараметром `max_depth` - максимальная глубина дерева - от 1 до 15. Для всех построенных моделей случайного леса F1-мера находится в диапазоне 0.54 - 0.58, AUC-ROC в диапазоне 0.81 - 0.82;
# - для моделей `Random Forest` было проанализировано 150 вариантов: с гиперпараметром `n_estimators` - количество деревьев - от 10 до 100 с шагом 10, и гиперпараметром `max_depth` - максимальная глубина - от 1 до 15. Модели случайного леса показали самые лучшие результаты в этой задаче: F1-мера для всех построенных моделей находися в диапазоне 0.57 - 0.61, AUC-ROC в диапазоне 0.83 - 0.84;
# - модель `Logistic Regression` была проанализирована в одном варианте с гиперпараметрами: `solver='liblinear'` - алгоритм, который будет строить модель. Модели логистической регрессии показали себя хуже всех в этой задаче: F1-мера для всех построенных моделей варьируется от 0.47 до 0.49, AUC-ROC = 0.74.
# 4. Модели были обучены на несбалансированных данных и сбалансированных 3-мя способами:
# - взвешивание классов;
# - увеличение выборки (upsampling);
# - уменьшение выборки (downsampling).
#
#   Все модели по метрикам очень похожи (отличаются на 0.01-0.02), но самые худшие результаты показывают модели, построенные на данных, сбалансированных с помощью техники downsampling - такие модели показывают результаты, хуже, чем даже модели, построенные на несбалансированных данных.
# 5. Для получения более высоких метрик для каждой из модели был подобран оптимальный порог, при котором модель показывает самые лучшие метрики.
# 6. Самые хорошие результаты показала модель `Random Forest` при использовании параметра class_weight = 'balanced' при пороге 0.5: F1=0.61, AUC-ROC= 0.84.
# 8. Эта же наилучшая модель на тестовых данных показала F1= 0.651, ROC_AUC= 0.83.
# 9. Для улучшения качества модели она была обучена на объединенной выборке (обучающая и валидационная) и заново протестирована на тестовой выборке: F1=0.653, AUC-ROC= 0.86.

# %% [markdown]
# ## Чек-лист готовности проекта

# %% [markdown]
# - [x]  Jupyter Notebook открыт
# - [x]  Весь код выполняется без ошибок
# - [x]  Ячейки с кодом расположены в порядке исполнения
# - [x]  Выполнен шаг 1: данные подготовлены
# - [x]  Выполнен шаг 2: задача исследована
#     - [x]  Исследован баланс классов
#     - [x]  Изучены модели без учёта дисбаланса
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 3: учтён дисбаланс
#     - [x]  Применено несколько способов борьбы с дисбалансом
#     - [x]  Написаны выводы по результатам исследования
# - [x]  Выполнен шаг 4: проведено тестирование
# - [x]  Удалось достичь *F1*-меры не менее 0.59
# - [x]  Исследована метрика *AUC-ROC*
